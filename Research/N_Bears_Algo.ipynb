# %%
import tensorflow as tf
# import plotly as px
import pandas as pd
# import matplotlib.pyplot as plt
import numpy as np
# import plotly.express as px
import copy
# from Modules.Technical_indicators import ATR, BB, RSI, ADX, MACD
# from plotly.subplots import make_subplots
# import plotly.graph_objs as go
# from Modules.Plotting import Compare_Plot, Compare_Plot_bar
import warnings
warnings.filterwarnings("ignore")
# Out:
# 2024-04-22 07:39:54.018096: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-04-22 07:39:54.018230: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-04-22 07:39:54.134561: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
df = pd.read_csv(r'/kaggle/input/btc-usd/BTC-USD.csv')
df['Date'] = pd.to_datetime(df['Date'])
df_time = df.set_index('Date')

# %%
df['Date'] = pd.to_datetime(df['Date'])
df.set_index('Date',inplace = True)
data = copy.deepcopy(df)
df.dropna(inplace = True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 3503 entries, 2014-09-17 to 2024-04-19
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Open       3503 non-null   float64
#  1   High       3503 non-null   float64
#  2   Low        3503 non-null   float64
#  3   Close      3503 non-null   float64
#  4   Adj Close  3503 non-null   float64
#  5   Volume     3503 non-null   int64
# dtypes: float64(5), int64(1)
# memory usage: 191.6 KB

# %%
df = df.drop(columns = ['Open','High','Low','Close','Volume'],axis = 1)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 3503 entries, 2014-09-17 to 2024-04-19
# Data columns (total 1 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Adj Close  3503 non-null   float64
# dtypes: float64(1)
# memory usage: 54.7 KB

# %%
labels_list = []
feature_list = []
window_size = 30
horizon = 1
feature_array = np.array(df)
for i in range(0, len(df['Adj Close'])-(window_size+horizon-1)):
    feature_list.append(np.array(feature_array[i:i+window_size]))
    labels_list.append(np.array(df['Adj Close'][i+window_size:i+window_size+horizon]))

# Convert the list of arrays to a numpy array
labels = np.array(labels_list)
feature = np.array(feature_list)

labels  = tf.convert_to_tensor(labels)
feature = tf.convert_to_tensor(feature)

# %%
labels.shape, feature.shape
# Out:
# (TensorShape([3473, 1]), TensorShape([3473, 30, 1]))

# %%
def make_train_test_splits(windows, labels, test_split = 0.15):
    split_size = int(len(windows)* (1-test_split))
    train_windows = windows[:split_size]
    train_labels = labels[:split_size]
    test_windows = windows[split_size:]
    test_labels = labels[split_size:]
    return train_windows, test_windows, train_labels, test_labels

# %%
train_windows, test_windows, train_labels, test_labels = make_train_test_splits(feature,labels)
train_windows.shape, (test_windows).shape, (train_labels).shape, (test_labels).shape
# Out:
# (TensorShape([2952, 30, 1]),
#  TensorShape([521, 30, 1]),
#  TensorShape([2952, 1]),
#  TensorShape([521, 1]))

# %%
batch_size = 32
def prepare_data_for_training(X_train, X_test,Y_train, Y_test, batch_size = 32):

    train_text_dataset = tf.data.Dataset.from_tensor_slices(X_train)
    train_labels_dataset = tf.data.Dataset.from_tensor_slices(Y_train)

    train_dataset = tf.data.Dataset.zip((train_text_dataset, train_labels_dataset))
    train_dataset = train_dataset.shuffle(buffer_size=len(X_train)).batch(batch_size).prefetch(tf.data.AUTOTUNE)

    test_text_dataset = tf.data.Dataset.from_tensor_slices(X_test)
    test_labels_dataset = tf.data.Dataset.from_tensor_slices(Y_test)

    test_dataset = tf.data.Dataset.zip((test_text_dataset, test_labels_dataset))
    test_dataset = test_dataset.shuffle(buffer_size=len(X_test)).batch(batch_size).prefetch(tf.data.AUTOTUNE)
    return train_dataset, test_dataset

# %%
train_dataset, val_dataset = prepare_data_for_training(X_train = train_windows, X_test= test_windows,Y_train = train_labels, Y_test =  test_labels , batch_size = 32)

# %%
# batch_size = 32
# train_text_dataset = tf.data.Dataset.from_tensor_slices(feature)
# train_labels_dataset = tf.data.Dataset.from_tensor_slices(labels)
# train_dataset = tf.data.Dataset.zip((train_text_dataset, train_labels_dataset))
# train_dataset = train_dataset.shuffle(buffer_size=len(feature)).batch(batch_size).prefetch(tf.data.AUTOTUNE)

# %%
from tensorflow.keras.callbacks import EarlyStopping
# callback = EarlyStopping(
#     monitor="loss",#quantity to monitor
#     min_delta=0.0001,#Minimum change in the monnitored quantity as an improvement
#     patience=20,#No of epochs with no improvement
#     verbose=1,
#     mode="auto",
#     restore_best_weights=True
# )

# %%
def create_callbacks(dir_name, experiment_name):
    """
    Creates callbacks for training.

    Args:
    - dir_name: target directory to store TensorBoard log files and model checkpoints
    - experiment_name: name of experiment directory

    Returns:
    - callbacks: list of callbacks
    """
    log_dir = dir_name + "/" + experiment_name + "/" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
    print(f"Saving TensorBoard log files to: {log_dir}")

    # TensorBoard callback for logging
    tensorboard_callback = TensorBoard(log_dir=log_dir)

    # ModelCheckpoint callback for saving the best model based on validation loss
    model_checkpoint_callback = ModelCheckpoint(filepath=f"{dir_name}/{experiment_name}/best_model.keras",
                                                monitor='val_loss',  # Monitor validation loss
                                                save_best_only=True,
                                                verbose=1)

    return [tensorboard_callback, model_checkpoint_callback]

# %% [markdown]
# ### N_BEATS custom layers

# %%
# class NBeatsBlock(tf.keras.layers.Layer):
#     def __init__(self,
#                 input_size:int,
#                 theta_size:int,
#                 horizon:int,
#                 n_neurons:int,
#                 n_layers:int,
#                 **kwargs):

#         super().__init__(**kwargs)

#         # Initialize attributes based on input parameters
#         self.input_size = input_size  # Size of the input time series
#         self.theta_size = theta_size  # Size of the theta vector
#         self.horizon = horizon  # Forecasting horizon
#         self.n_neurons = n_neurons  # Number of neurons in each hidden layer
#         self.n_layers = n_layers  # Number of hidden layers

#         # Define hidden layers with ReLU activation
#         self.hidden = [tf.keras.layers.Dense(n_neurons, activation="relu") for _ in range(n_layers)]

#         # Define theta layer with linear activation
#         self.theta_layer = tf.keras.layers.Dense(theta_size, activation="linear", name="theta")

#     def call(self, inputs):
#         x = inputs  # Input tensor
#         # Pass input through each hidden layer sequentially
#         for layer in self.hidden:
#             x = layer(x)
        
#         # Compute theta vector by passing output of last hidden layer through theta layer
#         theta = self.theta_layer(x)

#         # Split theta vector into backcast and forecast components
#         backcast, forecast = theta[:, :self.input_size], theta[:, -self.horizon:]

#         # Return backcast and forecast predictions
#         return backcast, forecast

# %%
# N_EPOCHS = 1000
# N_NEURONS = 512
# N_LAYERS  = 4
# N_STACKS = 30

# input_size = window_size * horizon
# theta_size = window_size + horizon

# input_size, theta_size

# %%
# window_size = 30
# horizon = 1

# class NBeatsBlock(tf.keras.layers.Layer):
#     def __init__(self,
#                 input_size:int,
#                 theta_size:int,
#                 horizon:int,
#                 n_neurons:int,
#                 n_layers:int,
#                 **kwargs):

#         super().__init__(**kwargs)

#         # Initialize attributes based on input parameters
#         self.input_size = input_size  # Size of the input time series
#         self.theta_size = theta_size  # Size of the theta vector
#         self.horizon = horizon  # Forecasting horizon
#         self.n_neurons = n_neurons  # Number of neurons in each hidden layer
#         self.n_layers = n_layers  # Number of hidden layers

#         # Define hidden layers with ReLU activation
#         self.hidden = [tf.keras.layers.Dense(n_neurons, activation="relu") for _ in range(n_layers)]

#         # Define theta layer with linear activation
#         self.theta_layer = tf.keras.layers.Dense(theta_size, activation="linear", name="theta")

#     def call(self, inputs):
#         x = inputs  # Input tensor
#         # Pass input through each hidden layer sequentially
#         for layer in self.hidden:
#             x = layer(x)
        
#         # Compute theta vector by passing output of last hidden layer through theta layer
#         theta = self.theta_layer(x)

#         # Split theta vector into backcast and forecast components
#         backcast, forecast = theta[:, :self.input_size], theta[:, -self.horizon:]

#         # Return backcast and forecast predictions
#         return backcast, forecast



# N_EPOCHS = 1000
# N_NEURONS = 512
# N_LAYERS  = 4
# N_STACKS = 30

# input_size = window_size * horizon
# theta_size = window_size + horizon

# from tensorflow.keras import layers 
# tf.random.set_seed(42)

# # Initialize the first N-Beats block layer
# nbeat_block_layer = NBeatsBlock(
#                                 input_size=input_size,
#                                 theta_size=theta_size,
#                                 horizon=horizon,
#                                 n_neurons=N_NEURONS,
#                                 n_layers=N_LAYERS,
#                                 name='Initial_block'
#                                 )

# # Define input layer for the stacked model
# stack_input = layers.Input(shape=(input_size), name='stack_input')

# # Apply the initial N-Beats block layer to the input layer
# backcast, forecast = nbeat_block_layer(stack_input)

# # Calculate residuals by subtracting the backcast predictions from the input
# residuals = layers.subtract([stack_input, backcast], name="subtract_00")

# # Iterate over the remaining N-Beats blocks to create a stacked architecture
# for i, _ in enumerate(range(N_STACKS - 1)):
#     # Apply N-Beats block to residuals from the previous block
#     backcast, block_forecast = NBeatsBlock(
#                                 input_size=input_size,
#                                 theta_size=theta_size,
#                                 horizon=horizon,
#                                 n_neurons=N_NEURONS,
#                                 n_layers=N_LAYERS,
#                                 name=f'NBeatsBlock_{i}'
#                                 )(residuals)

#     # Update residuals by subtracting backcast predictions
#     residuals = layers.subtract([residuals, backcast], name=f"subtract_{i}")
#     # Update forecast by adding block's forecast predictions
#     forecast = layers.add([forecast, block_forecast], name=f"add_{i}")

# # Define the N-BEATS model using the input and output layers
# N_BEATS_MODEL = tf.keras.Model(
#                                 inputs=stack_input,
#                                 outputs=forecast,
#                                 name='Model_N_BEATS'
#                                 )

# # Compile the model with Mean Absolute Error loss, Adam optimizer, and additional metrics
# N_BEATS_MODEL.compile(loss='mae', optimizer=tf.keras.optimizers.Adam(0.001), metrics=["mae", "mse"])

# # Display the summary of the model architecture
# N_BEATS_MODEL.summary()

# %%
window_size = 30
horizon = 1

class NBeatsBlock(tf.keras.layers.Layer):
    def __init__(self,
                input_size:int,
                theta_size:int,
                horizon:int,
                n_neurons:int,
                n_layers:int,
                **kwargs):

        super().__init__(**kwargs)

        # Initialize attributes based on input parameters
        self.input_size = input_size  # Size of the input time series
        self.theta_size = theta_size  # Size of the theta vector
        self.horizon = horizon  # Forecasting horizon
        self.n_neurons = n_neurons  # Number of neurons in each hidden layer
        self.n_layers = n_layers  # Number of hidden layers

        # Define hidden layers with ReLU activation
        self.hidden = [tf.keras.layers.Dense(n_neurons, activation="relu") for _ in range(n_layers)]

        # Define theta layer with linear activation
        self.theta_layer = tf.keras.layers.Dense(theta_size, activation="linear", name="theta")

    def call(self, inputs):
        x = inputs  # Input tensor
        # Pass input through each hidden layer sequentially
        for layer in self.hidden:
            x = layer(x)
        
        # Compute theta vector by passing output of last hidden layer through theta layer
        theta = self.theta_layer(x)

        # Split theta vector into backcast and forecast components
        backcast, forecast = theta[:, :self.input_size], theta[:, -self.horizon:]

        # Return backcast and forecast predictions
        return backcast, forecast



N_EPOCHS = 1000
N_NEURONS = 512
N_LAYERS  = 4
N_STACKS = 30

input_size = window_size * horizon
theta_size = window_size + horizon

from tensorflow.keras import layers 
tf.random.set_seed(42)

# Initialize the first N-Beats block layer
nbeat_block_layer = NBeatsBlock(
                                input_size=input_size,
                                theta_size=theta_size,
                                horizon=horizon,
                                n_neurons=N_NEURONS,
                                n_layers=N_LAYERS,
                                name='Initial_block'
                                )

# Define input layer for the stacked model
stack_input = layers.Input(shape=(input_size,), name='stack_input')

# Apply the initial N-Beats block layer to the input layer
backcast, forecast = nbeat_block_layer(stack_input)

# Calculate residuals by subtracting the backcast predictions from the input
residuals = layers.subtract([stack_input, backcast], name="subtract_00")

# Iterate over the remaining N-Beats blocks to create a stacked architecture
for i, _ in enumerate(range(N_STACKS - 1)):
    # Apply N-Beats block to residuals from the previous block
    backcast, block_forecast = NBeatsBlock(
                                input_size=input_size,
                                theta_size=theta_size,
                                horizon=horizon,
                                n_neurons=N_NEURONS,
                                n_layers=N_LAYERS,
                                name=f'NBeatsBlock_{i}'
                                )(residuals)

    # Update residuals by subtracting backcast predictions
    residuals = layers.subtract([residuals, backcast], name=f"subtract_{i}")
    # Update forecast by adding block's forecast predictions
    forecast = layers.add([forecast, block_forecast], name=f"add_{i}")

# Define the N-BEATS model using the input and output layers
N_BEATS_MODEL = tf.keras.Model(
                                inputs=stack_input,
                                outputs=forecast,
                                name='Model_N_BEATS'
                                )

# Compile the model with Mean Absolute Error loss, Adam optimizer, and additional metrics
N_BEATS_MODEL.compile(loss='mae', optimizer=tf.keras.optimizers.Adam(0.001), metrics=["mae", "mse"])

# Display the summary of the model architecture
N_BEATS_MODEL.summary()
# Out:
# Model: "Model_N_BEATS"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ stack_input         │ (None, 30)        │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ Initial_block       │ [(None, 30),      │    819,743 │ stack_input[0][0] │
# │ (NBeatsBlock)       │ (None, 1)]        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ subtract_00         │ (None, 30)        │          0 │ stack_input[0][0… │
# │ (Subtract)          │                   │            │ Initial_block[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ NBeatsBlock_0       │ [(None, 30),      │    819,743 │ subtract_00[0][0] │
# │ (NBeatsBlock)       │ (None, 1)]        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ subtract_0          │ (None, 30)        │          0 │ subtract_00[0][0… │
# │ (Subtract)          │                   │            │ NBeatsBlock_0[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ NBeatsBlock_1       │ [(None, 30),      │    819,743 │ subtract_0[0][0]  │
# │ (NBeatsBlock)       │ (None, 1)]        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ subtract_1          │ (None, 30)        │          0 │ subtract_0[0][0], │
# │ (Subtract)          │                   │            │ NBeatsBlock_1[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ NBeatsBlock_2       │ [(None, 30),      │    819,743 │ subtract_1[0][0]  │
# │ (NBeatsBlock)       │ (None, 1)]        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ subtract_2          │ (None, 30)        │          0 │ subtract_1[0][0], │
# │ (Subtract)          │                   │            │ NBeatsBlock_2[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ NBeatsBlock_3       │ [(None, 30),      │    819,743 │ subtract_2[0][0]  │
# │ (NBeatsBlock)       │ (None, 1)]        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ subtract_3          │ (None, 30)        │          0 │ subtract_2[0][0], │
# │ (Subtract)          │                   │            │ NBeatsBlock_3[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ NBeatsBlock_4       │ [(None, 30),      │    819,743 │ subtract_3[0][0]  │
# │ (NBeatsBlock)       │ (None, 1)]        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ subtract_4          │ (None, 30)        │          0 │ subtract_3[0][0], │
# │ (Subtract)          │                   │            │ NBeatsBlock_4[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ NBeatsBlock_5       │ [(None, 30),      │    819,743 │ subtract_4[0][0]  │
# │ (NBeatsBlock)       │ (None, 1)]        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ subtract_5          │ (None, 30)        │          0 │ subtract_4[0][0], │
# │ (Subtract)          │                   │            │ NBeatsBlock_5[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ NBeatsBlock_6       │ [(None, 30),      │    819,743 │ subtract_5[0][0]  │
# │ (NBeatsBlock)       │ (None, 1)]        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ subtract_6          │ (None, 30)        │          0 │ subtract_5[0][0], │
# │ (Subtract)          │                   │            │ NBeatsBlock_6[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ NBeatsBlock_7       │ [(None, 30),      │    819,743 │ subtract_6[0][0]  │
# │ (NBeatsBlock)       │ (None, 1)]        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ subtract_7          │ (None, 30)        │          0 │ subtract_6[0][0], │
# │ (Subtract)          │                   │            │ NBeatsBlock_7[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ NBeatsBlock_8       │ [(None, 30),      │    819,743 │ subtract_7[0][0]  │
# │ (NBeatsBlock)       │ (None, 1)]        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ subtract_8          │ (None, 30)        │          0 │ subtract_7[0][0], │
# │ (Subtract)          │                   │            │ NBeatsBlock_8[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ NBeatsBlock_9       │ [(None, 30),      │    819,743 │ subtract_8[0][0]  │
# │ (NBeatsBlock)       │ (None, 1)]        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ subtract_9          │ (None, 30)        │          0 │ subtract_8[0][0], │
# │ (Subtract)          │                   │            │ NBeatsBlock_9[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ NBeatsBlock_10      │ [(None, 30),      │    819,743 │ subtract_9[0][0]  │
# │ (NBeatsBlock)       │ (None, 1)]        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ subtract_10         │ (None, 30)        │          0 │ subtract_9[0][0], │
# │ (Subtract)          │                   │            │ NBeatsBlock_10[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ NBeatsBlock_11      │ [(None, 30),      │    819,743 │ subtract_10[0][0] │
# │ (NBeatsBlock)       │ (None, 1)]        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ subtract_11         │ (None, 30)        │          0 │ subtract_10[0][0… │
# │ (Subtract)          │                   │            │ NBeatsBlock_11[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ NBeatsBlock_12      │ [(None, 30),      │    819,743 │ subtract_11[0][0] │
# │ (NBeatsBlock)       │ (None, 1)]        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ subtract_12         │ (None, 30)        │          0 │ subtract_11[0][0… │
# │ (Subtract)          │                   │            │ NBeatsBlock_12[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ NBeatsBlock_13      │ [(None, 30),      │    819,743 │ subtract_12[0][0] │
# │ (NBeatsBlock)       │ (None, 1)]        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ subtract_13         │ (None, 30)        │          0 │ subtract_12[0][0… │
# │ (Subtract)          │                   │            │ NBeatsBlock_13[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ NBeatsBlock_14      │ [(None, 30),      │    819,743 │ subtract_13[0][0] │
# │ (NBeatsBlock)       │ (None, 1)]        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_0 (Add)         │ (None, 1)         │          0 │ Initial_block[0]… │
# │                     │                   │            │ NBeatsBlock_0[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ subtract_14         │ (None, 30)        │          0 │ subtract_13[0][0… │
# │ (Subtract)          │                   │            │ NBeatsBlock_14[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_1 (Add)         │ (None, 1)         │          0 │ add_0[0][0],      │
# │                     │                   │            │ NBeatsBlock_1[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ NBeatsBlock_15      │ [(None, 30),      │    819,743 │ subtract_14[0][0] │
# │ (NBeatsBlock)       │ (None, 1)]        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_2 (Add)         │ (None, 1)         │          0 │ add_1[0][0],      │
# │                     │                   │            │ NBeatsBlock_2[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ subtract_15         │ (None, 30)        │          0 │ subtract_14[0][0… │
# │ (Subtract)          │                   │            │ NBeatsBlock_15[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_3 (Add)         │ (None, 1)         │          0 │ add_2[0][0],      │
# │                     │                   │            │ NBeatsBlock_3[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ NBeatsBlock_16      │ [(None, 30),      │    819,743 │ subtract_15[0][0] │
# │ (NBeatsBlock)       │ (None, 1)]        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_4 (Add)         │ (None, 1)         │          0 │ add_3[0][0],      │
# │                     │                   │            │ NBeatsBlock_4[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ subtract_16         │ (None, 30)        │          0 │ subtract_15[0][0… │
# │ (Subtract)          │                   │            │ NBeatsBlock_16[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_5 (Add)         │ (None, 1)         │          0 │ add_4[0][0],      │
# │                     │                   │            │ NBeatsBlock_5[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ NBeatsBlock_17      │ [(None, 30),      │    819,743 │ subtract_16[0][0] │
# │ (NBeatsBlock)       │ (None, 1)]        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_6 (Add)         │ (None, 1)         │          0 │ add_5[0][0],      │
# │                     │                   │            │ NBeatsBlock_6[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ subtract_17         │ (None, 30)        │          0 │ subtract_16[0][0… │
# │ (Subtract)          │                   │            │ NBeatsBlock_17[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_7 (Add)         │ (None, 1)         │          0 │ add_6[0][0],      │
# │                     │                   │            │ NBeatsBlock_7[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ NBeatsBlock_18      │ [(None, 30),      │    819,743 │ subtract_17[0][0] │
# │ (NBeatsBlock)       │ (None, 1)]        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_8 (Add)         │ (None, 1)         │          0 │ add_7[0][0],      │
# │                     │                   │            │ NBeatsBlock_8[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ subtract_18         │ (None, 30)        │          0 │ subtract_17[0][0… │
# │ (Subtract)          │                   │            │ NBeatsBlock_18[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_9 (Add)         │ (None, 1)         │          0 │ add_8[0][0],      │
# │                     │                   │            │ NBeatsBlock_9[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ NBeatsBlock_19      │ [(None, 30),      │    819,743 │ subtract_18[0][0] │
# │ (NBeatsBlock)       │ (None, 1)]        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_10 (Add)        │ (None, 1)         │          0 │ add_9[0][0],      │
# │                     │                   │            │ NBeatsBlock_10[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ subtract_19         │ (None, 30)        │          0 │ subtract_18[0][0… │
# │ (Subtract)          │                   │            │ NBeatsBlock_19[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_11 (Add)        │ (None, 1)         │          0 │ add_10[0][0],     │
# │                     │                   │            │ NBeatsBlock_11[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ NBeatsBlock_20      │ [(None, 30),      │    819,743 │ subtract_19[0][0] │
# │ (NBeatsBlock)       │ (None, 1)]        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_12 (Add)        │ (None, 1)         │          0 │ add_11[0][0],     │
# │                     │                   │            │ NBeatsBlock_12[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ subtract_20         │ (None, 30)        │          0 │ subtract_19[0][0… │
# │ (Subtract)          │                   │            │ NBeatsBlock_20[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_13 (Add)        │ (None, 1)         │          0 │ add_12[0][0],     │
# │                     │                   │            │ NBeatsBlock_13[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ NBeatsBlock_21      │ [(None, 30),      │    819,743 │ subtract_20[0][0] │
# │ (NBeatsBlock)       │ (None, 1)]        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_14 (Add)        │ (None, 1)         │          0 │ add_13[0][0],     │
# │                     │                   │            │ NBeatsBlock_14[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ subtract_21         │ (None, 30)        │          0 │ subtract_20[0][0… │
# │ (Subtract)          │                   │            │ NBeatsBlock_21[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_15 (Add)        │ (None, 1)         │          0 │ add_14[0][0],     │
# │                     │                   │            │ NBeatsBlock_15[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ NBeatsBlock_22      │ [(None, 30),      │    819,743 │ subtract_21[0][0] │
# │ (NBeatsBlock)       │ (None, 1)]        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_16 (Add)        │ (None, 1)         │          0 │ add_15[0][0],     │
# │                     │                   │            │ NBeatsBlock_16[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ subtract_22         │ (None, 30)        │          0 │ subtract_21[0][0… │
# │ (Subtract)          │                   │            │ NBeatsBlock_22[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_17 (Add)        │ (None, 1)         │          0 │ add_16[0][0],     │
# │                     │                   │            │ NBeatsBlock_17[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ NBeatsBlock_23      │ [(None, 30),      │    819,743 │ subtract_22[0][0] │
# │ (NBeatsBlock)       │ (None, 1)]        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_18 (Add)        │ (None, 1)         │          0 │ add_17[0][0],     │
# │                     │                   │            │ NBeatsBlock_18[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ subtract_23         │ (None, 30)        │          0 │ subtract_22[0][0… │
# │ (Subtract)          │                   │            │ NBeatsBlock_23[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_19 (Add)        │ (None, 1)         │          0 │ add_18[0][0],     │
# │                     │                   │            │ NBeatsBlock_19[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ NBeatsBlock_24      │ [(None, 30),      │    819,743 │ subtract_23[0][0] │
# │ (NBeatsBlock)       │ (None, 1)]        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_20 (Add)        │ (None, 1)         │          0 │ add_19[0][0],     │
# │                     │                   │            │ NBeatsBlock_20[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ subtract_24         │ (None, 30)        │          0 │ subtract_23[0][0… │
# │ (Subtract)          │                   │            │ NBeatsBlock_24[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_21 (Add)        │ (None, 1)         │          0 │ add_20[0][0],     │
# │                     │                   │            │ NBeatsBlock_21[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ NBeatsBlock_25      │ [(None, 30),      │    819,743 │ subtract_24[0][0] │
# │ (NBeatsBlock)       │ (None, 1)]        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_22 (Add)        │ (None, 1)         │          0 │ add_21[0][0],     │
# │                     │                   │            │ NBeatsBlock_22[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ subtract_25         │ (None, 30)        │          0 │ subtract_24[0][0… │
# │ (Subtract)          │                   │            │ NBeatsBlock_25[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_23 (Add)        │ (None, 1)         │          0 │ add_22[0][0],     │
# │                     │                   │            │ NBeatsBlock_23[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ NBeatsBlock_26      │ [(None, 30),      │    819,743 │ subtract_25[0][0] │
# │ (NBeatsBlock)       │ (None, 1)]        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_24 (Add)        │ (None, 1)         │          0 │ add_23[0][0],     │
# │                     │                   │            │ NBeatsBlock_24[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ subtract_26         │ (None, 30)        │          0 │ subtract_25[0][0… │
# │ (Subtract)          │                   │            │ NBeatsBlock_26[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_25 (Add)        │ (None, 1)         │          0 │ add_24[0][0],     │
# │                     │                   │            │ NBeatsBlock_25[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ NBeatsBlock_27      │ [(None, 30),      │    819,743 │ subtract_26[0][0] │
# │ (NBeatsBlock)       │ (None, 1)]        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_26 (Add)        │ (None, 1)         │          0 │ add_25[0][0],     │
# │                     │                   │            │ NBeatsBlock_26[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ subtract_27         │ (None, 30)        │          0 │ subtract_26[0][0… │
# │ (Subtract)          │                   │            │ NBeatsBlock_27[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_27 (Add)        │ (None, 1)         │          0 │ add_26[0][0],     │
# │                     │                   │            │ NBeatsBlock_27[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ NBeatsBlock_28      │ [(None, 30),      │    819,743 │ subtract_27[0][0] │
# │ (NBeatsBlock)       │ (None, 1)]        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_28 (Add)        │ (None, 1)         │          0 │ add_27[0][0],     │
# │                     │                   │            │ NBeatsBlock_28[0… │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 24,592,290 (93.81 MB)
#  Trainable params: 24,592,290 (93.81 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
N_BEATS_MODEL.fit(train_dataset, 
                  epochs=N_EPOCHS,validation_data = val_dataset,
                  callbacks=[
                      tf.keras.callbacks.EarlyStopping(monitor="val_loss", patience=100, restore_best_weights=True),
                      tf.keras.callbacks.ReduceLROnPlateau(monitor="val_loss", patience=50, verbose=1),
                      create_callbacks('Model', N_BEATS_MODEL.name)
                  ])
# Out:
# Saving TensorBoard log files to: Model/Model_N_BEATS/20240422-074513
# Epoch 1/1000
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1713771966.558473      82 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 196ms/step - loss: 28260.6348 - mae: 28260.6348 - mse: 19966224384.0000
# Epoch 1: val_loss improved from inf to 4142.19971, saving model to Model/Model_N_BEATS/best_model.keras
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 79s 281ms/step - loss: 28052.1465 - mae: 28052.1465 - mse: 19806924800.0000 - val_loss: 4142.1997 - val_mae: 4142.1997 - val_mse: 20811308.0000 - learning_rate: 0.0010
# Epoch 2/1000
# 92/93 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 1153.8470 - mae: 1153.8470 - mse: 5195560.5000
# Epoch 2: val_loss improved from 4142.19971 to 2249.90894, saving model to Model/Model_N_BEATS/best_model.keras
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 5s 49ms/step - loss: 1148.8187 - mae: 1148.8187 - mse: 5158460.0000 - val_loss: 2249.9089 - val_mae: 2249.9089 - val_mse: 7125272.5000 - learning_rate: 0.0010
# Epoch 3/1000
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 793.9354 - mae: 793.9354 - mse: 2716549.2500
# Epoch 3: val_loss improved from 2249.90894 to 2116.54199, saving model to Model/Model_N_BEATS/best_model.keras
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 5s 51ms/step - loss: 793.6957 - mae: 793.6957 - mse: 2713759.7500 - val_loss: 2116.5420 - val_mae: 2116.5420 - val_mse: 7149871.5000 - learning_rate: 0.0010
# Epoch 4/1000
# 92/93 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 708.3306 - mae: 708.3306 - mse: 2124262.2500
# Epoch 4: val_loss improved from 2116.54199 to 1445.45276, saving model to Model/Model_N_BEATS/best_model.keras
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 5s 49ms/step - loss: 706.7076 - mae: 706.7076 - mse: 2113757.0000 - val_loss: 1445.4528 - val_mae: 1445.4528 - val_mse: 3363999.5000 - learning_rate: 0.0010
# Epoch 5/1000
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 608.6124 - mae: 608.6124 - mse: 1525586.2500
# Epoch 5: val_loss improved from 1445.45276 to 830.78638, saving model to Model/Model_N_BEATS/best_model.keras
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 5s 51ms/step - loss: 608.4299 - mae: 608.4299 - mse: 1524742.2500 - val_loss: 830.7864 - val_mae: 830.7864 - val_mse: 1716839.7500 - learning_rate: 0.0010
# Epoch 6/1000
# 92/93 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 587.2689 - mae: 587.2689 - mse: 1385356.8750
# Epoch 6: val_loss did not improve from 830.78638
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - loss: 587.2634 - mae: 587.2634 - mse: 1385524.6250 - val_loss: 1476.4006 - val_mae: 1476.4006 - val_mse: 3308913.0000 - learning_rate: 0.0010
# Epoch 7/1000
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 577.8124 - mae: 577.8124 - mse: 1294416.1250
# Epoch 7: val_loss did not improve from 830.78638
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 3s 32ms/step - loss: 577.2897 - mae: 577.2897 - mse: 1292518.2500 - val_loss: 1095.6831 - val_mae: 1095.6831 - val_mse: 2099539.0000 - learning_rate: 0.0010
# Epoch 8/1000
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 684.3980 - mae: 684.3980 - mse: 1782896.1250
# Epoch 8: val_loss improved from 830.78638 to 711.21454, saving model to Model/Model_N_BEATS/best_model.keras
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 5s 52ms/step - loss: 684.1813 - mae: 684.1813 - mse: 1781804.0000 - val_loss: 711.2145 - val_mae: 711.2145 - val_mse: 1327946.1250 - learning_rate: 0.0010
# Epoch 9/1000
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 512.6011 - mae: 512.6011 - mse: 1159264.1250
# Epoch 9: val_loss did not improve from 711.21454
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - loss: 513.1558 - mae: 513.1558 - mse: 1161507.8750 - val_loss: 1187.6049 - val_mae: 1187.6049 - val_mse: 2533228.7500 - learning_rate: 0.0010
# Epoch 10/1000
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 477.2473 - mae: 477.2473 - mse: 1012963.0000
# Epoch 10: val_loss did not improve from 711.21454
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 3s 32ms/step - loss: 477.1515 - mae: 477.1515 - mse: 1012619.2500 - val_loss: 777.6561 - val_mae: 777.6561 - val_mse: 1425361.0000 - learning_rate: 0.0010
# Epoch 11/1000
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 435.3371 - mae: 435.3371 - mse: 820388.3125
# Epoch 11: val_loss did not improve from 711.21454
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 3s 33ms/step - loss: 435.6214 - mae: 435.6214 - mse: 821155.9375 - val_loss: 1700.8563 - val_mae: 1700.8563 - val_mse: 4279610.5000 - learning_rate: 0.0010
# Epoch 12/1000
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 488.6566 - mae: 488.6566 - mse: 946122.0625
# Epoch 12: val_loss did not improve from 711.21454
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - loss: 488.5078 - mae: 488.5078 - mse: 945949.8125 - val_loss: 2369.7170 - val_mae: 2369.7170 - val_mse: 7649894.0000 - learning_rate: 0.0010
# Epoch 13/1000
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 576.3674 - mae: 576.3674 - mse: 1542809.5000
# Epoch 13: val_loss did not improve from 711.21454
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - loss: 575.5100 - mae: 575.5100 - mse: 1537950.0000 - val_loss: 1430.6975 - val_mae: 1430.6975 - val_mse: 3220801.0000 - learning_rate: 0.0010
# Epoch 14/1000
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 430.5697 - mae: 430.5697 - mse: 764030.9375
# Epoch 14: val_loss improved from 711.21454 to 677.41144, saving model to Model/Model_N_BEATS/best_model.keras
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 5s 52ms/step - loss: 430.6801 - mae: 430.6801 - mse: 764506.0000 - val_loss: 677.4114 - val_mae: 677.4114 - val_mse: 1080987.8750 - learning_rate: 0.0010
# Epoch 15/1000
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 514.0601 - mae: 514.0601 - mse: 1081357.6250
# Epoch 15: val_loss did not improve from 677.41144
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - loss: 513.9638 - mae: 513.9638 - mse: 1081386.1250 - val_loss: 817.5438 - val_mae: 817.5438 - val_mse: 1551251.3750 - learning_rate: 0.0010
# Epoch 16/1000
# 92/93 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 475.2913 - mae: 475.2913 - mse: 974143.8125
# Epoch 16: val_loss did not improve from 677.41144
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - loss: 475.3997 - mae: 475.3997 - mse: 973541.3125 - val_loss: 839.8463 - val_mae: 839.8463 - val_mse: 1535156.8750 - learning_rate: 0.0010
# Epoch 17/1000
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 493.5787 - mae: 493.5787 - mse: 943304.1875
# Epoch 17: val_loss did not improve from 677.41144
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 493.5509 - mae: 493.5509 - mse: 943519.6875 - val_loss: 829.9423 - val_mae: 829.9423 - val_mse: 1504669.1250 - learning_rate: 0.0010
# Epoch 18/1000
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 429.6873 - mae: 429.6873 - mse: 755682.1250
# Epoch 18: val_loss did not improve from 677.41144
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - loss: 429.4243 - mae: 429.4243 - mse: 755000.4375 - val_loss: 696.7306 - val_mae: 696.7306 - val_mse: 1265468.6250 - learning_rate: 0.0010
# Epoch 19/1000
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 441.3467 - mae: 441.3467 - mse: 850095.8125
# Epoch 19: val_loss did not improve from 677.41144
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - loss: 441.2176 - mae: 441.2176 - mse: 849234.2500 - val_loss: 690.9826 - val_mae: 690.9826 - val_mse: 1156802.2500 - learning_rate: 0.0010
# Epoch 20/1000
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 443.3602 - mae: 443.3602 - mse: 840575.1875
# Epoch 20: val_loss did not improve from 677.41144
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - loss: 443.3159 - mae: 443.3159 - mse: 840185.6250 - val_loss: 1006.9079 - val_mae: 1006.9079 - val_mse: 1888173.6250 - learning_rate: 0.0010
# Epoch 21/1000
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 442.0748 - mae: 442.0748 - mse: 926509.2500
# Epoch 21: val_loss did not improve from 677.41144
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - loss: 441.8476 - mae: 441.8476 - mse: 924981.9375 - val_loss: 1477.9866 - val_mae: 1477.9866 - val_mse: 3386690.2500 - learning_rate: 0.0010
# Epoch 22/1000
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 443.1232 - mae: 443.1232 - mse: 735464.2500
# Epoch 22: val_loss did not improve from 677.41144
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 3s 32ms/step - loss: 442.8867 - mae: 442.8867 - mse: 735248.2500 - val_loss: 1866.2242 - val_mae: 1866.2242 - val_mse: 4947448.5000 - learning_rate: 0.0010
# Epoch 23/1000
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 538.9227 - mae: 538.9227 - mse: 1176891.0000
# Epoch 23: val_loss did not improve from 677.41144
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - loss: 538.3821 - mae: 538.3821 - mse: 1174552.3750 - val_loss: 1086.1400 - val_mae: 1086.1400 - val_mse: 2359315.5000 - learning_rate: 0.0010
# Epoch 24/1000
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 412.1942 - mae: 412.1942 - mse: 698339.9375
# Epoch 24: val_loss did not improve from 677.41144
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - loss: 412.6322 - mae: 412.6322 - mse: 699679.6250 - val_loss: 730.8278 - val_mae: 730.8278 - val_mse: 1247241.6250 - learning_rate: 0.0010
# Epoch 25/1000
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 376.9698 - mae: 376.9698 - mse: 608177.9375
# Epoch 25: val_loss did not improve from 677.41144
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - loss: 377.3612 - mae: 377.3612 - mse: 609440.5625 - val_loss: 857.6123 - val_mae: 857.6123 - val_mse: 1689101.2500 - learning_rate: 0.0010
# Epoch 26/1000
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 462.3157 - mae: 462.3157 - mse: 818292.1250
# Epoch 26: val_loss did not improve from 677.41144
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - loss: 462.1903 - mae: 462.1903 - mse: 818035.6875 - val_loss: 781.6694 - val_mae: 781.6694 - val_mse: 1305588.1250 - learning_rate: 0.0010
# Epoch 27/1000
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 387.7355 - mae: 387.7355 - mse: 647928.3750
# Epoch 27: val_loss improved from 677.41144 to 673.53363, saving model to Model/Model_N_BEATS/best_model.keras
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 5s 50ms/step - loss: 388.1884 - mae: 388.1884 - mse: 649028.9375 - val_loss: 673.5336 - val_mae: 673.5336 - val_mse: 1177329.8750 - learning_rate: 0.0010
# Epoch 28/1000
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 375.9274 - mae: 375.9274 - mse: 683514.3125
# Epoch 28: val_loss did not improve from 673.53363
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - loss: 376.1828 - mae: 376.1828 - mse: 683890.6250 - val_loss: 883.3072 - val_mae: 883.3072 - val_mse: 1614156.2500 - learning_rate: 0.0010
# Epoch 29/1000
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 431.4771 - mae: 431.4771 - mse: 786431.1250
# Epoch 29: val_loss did not improve from 673.53363
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - loss: 431.3930 - mae: 431.3930 - mse: 786363.2500 - val_loss: 1576.3083 - val_mae: 1576.3083 - val_mse: 3852820.5000 - learning_rate: 0.0010
# Epoch 30/1000
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 523.3577 - mae: 523.3577 - mse: 1107542.5000
# Epoch 30: val_loss improved from 673.53363 to 654.23029, saving model to Model/Model_N_BEATS/best_model.keras
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 4s 48ms/step - loss: 522.5692 - mae: 522.5692 - mse: 1104950.2500 - val_loss: 654.2303 - val_mae: 654.2303 - val_mse: 1082121.0000 - learning_rate: 0.0010
# Epoch 31/1000
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 398.8939 - mae: 398.8939 - mse: 693613.0625
# Epoch 31: val_loss did not improve from 654.23029
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - loss: 399.7043 - mae: 399.7043 - mse: 696635.7500 - val_loss: 678.4680 - val_mae: 678.4680 - val_mse: 1243625.6250 - learning_rate: 0.0010
# Epoch 32/1000
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 597.2816 - mae: 597.2816 - mse: 1505787.2500
# Epoch 32: val_loss did not improve from 654.23029
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - loss: 596.6957 - mae: 596.6957 - mse: 1503132.7500 - val_loss: 704.8223 - val_mae: 704.8223 - val_mse: 1196387.0000 - learning_rate: 0.0010
# Epoch 33/1000
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 432.4270 - mae: 432.4270 - mse: 787741.1250
# Epoch 33: val_loss improved from 654.23029 to 628.45392, saving model to Model/Model_N_BEATS/best_model.keras
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 4s 48ms/step - loss: 432.3128 - mae: 432.3128 - mse: 787505.8750 - val_loss: 628.4539 - val_mae: 628.4539 - val_mse: 1074317.3750 - learning_rate: 0.0010
# Epoch 34/1000
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 437.8065 - mae: 437.8065 - mse: 886463.7500
# Epoch 34: val_loss did not improve from 628.45392
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - loss: 437.7704 - mae: 437.7704 - mse: 885667.8125 - val_loss: 721.4253 - val_mae: 721.4253 - val_mse: 1196835.3750 - learning_rate: 0.0010
# Epoch 35/1000
# 92/93 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 361.4006 - mae: 361.4006 - mse: 572612.2500
# Epoch 35: val_loss did not improve from 628.45392
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - loss: 362.2699 - mae: 362.2699 - mse: 574907.1875 - val_loss: 39683.1914 - val_mae: 39683.1914 - val_mse: 1819202688.0000 - learning_rate: 0.0010
# Epoch 36/1000
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 2085.5164 - mae: 2085.5164 - mse: 65882580.0000
# Epoch 36: val_loss did not improve from 628.45392
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - loss: 2076.0056 - mae: 2076.0056 - mse: 65375144.0000 - val_loss: 2201.3210 - val_mae: 2201.3210 - val_mse: 6539198.5000 - learning_rate: 0.0010
# Epoch 37/1000
# 91/93 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 763.9172 - mae: 763.9172 - mse: 2246115.0000
# Epoch 37: val_loss did not improve from 628.45392
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - loss: 759.8231 - mae: 759.8231 - mse: 2228213.2500 - val_loss: 698.1158 - val_mae: 698.1158 - val_mse: 1206848.1250 - learning_rate: 0.0010
# Epoch 38/1000
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 449.3944 - mae: 449.3944 - mse: 873243.6875
# Epoch 38: val_loss did not improve from 628.45392
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - loss: 449.5033 - mae: 449.5033 - mse: 873573.4375 - val_loss: 2061.3220 - val_mae: 2061.3220 - val_mse: 5998056.0000 - learning_rate: 0.0010
# Epoch 39/1000
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 548.0244 - mae: 548.0244 - mse: 1226038.8750
# Epoch 39: val_loss did not improve from 628.45392
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - loss: 547.2513 - mae: 547.2513 - mse: 1223452.7500 - val_loss: 670.6022 - val_mae: 670.6022 - val_mse: 1175338.0000 - learning_rate: 0.0010
# Epoch 40/1000
# 92/93 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 456.5159 - mae: 456.5159 - mse: 879434.5000
# Epoch 40: val_loss did not improve from 628.45392
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - loss: 456.3508 - mae: 456.3508 - mse: 878906.0000 - val_loss: 895.1265 - val_mae: 895.1265 - val_mse: 1653332.0000 - learning_rate: 0.0010
# Epoch 41/1000
# 92/93 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 424.7471 - mae: 424.7471 - mse: 785955.2500
# Epoch 41: val_loss did not improve from 628.45392
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - loss: 424.6404 - mae: 424.6404 - mse: 785445.0000 - val_loss: 676.6833 - val_mae: 676.6833 - val_mse: 1200861.1250 - learning_rate: 0.0010
# Epoch 42/1000
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 405.1359 - mae: 405.1359 - mse: 680957.3750
# Epoch 42: val_loss did not improve from 628.45392
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 3s 32ms/step - loss: 405.0576 - mae: 405.0576 - mse: 681038.6250 - val_loss: 776.7145 - val_mae: 776.7145 - val_mse: 1430077.5000 - learning_rate: 0.0010
# Epoch 43/1000
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 428.7112 - mae: 428.7112 - mse: 785931.0625
# Epoch 43: val_loss did not improve from 628.45392
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - loss: 428.5902 - mae: 428.5902 - mse: 785785.9375 - val_loss: 674.5891 - val_mae: 674.5891 - val_mse: 1145958.7500 - learning_rate: 0.0010
# Epoch 44/1000
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 410.8800 - mae: 410.8800 - mse: 775356.3750
# Epoch 44: val_loss did not improve from 628.45392
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - loss: 410.8653 - mae: 410.8653 - mse: 775202.3750 - val_loss: 679.2551 - val_mae: 679.2551 - val_mse: 1157325.2500 - learning_rate: 0.0010
# Epoch 45/1000
# 92/93 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 373.6128 - mae: 373.6128 - mse: 633264.5000
# Epoch 45: val_loss did not improve from 628.45392
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - loss: 373.9443 - mae: 373.9443 - mse: 634251.6250 - val_loss: 748.0182 - val_mae: 748.0182 - val_mse: 1278587.8750 - learning_rate: 0.0010
# Epoch 46/1000
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 386.7728 - mae: 386.7728 - mse: 633535.0000
# Epoch 46: val_loss did not improve from 628.45392
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - loss: 386.8735 - mae: 386.8735 - mse: 634066.3125 - val_loss: 648.5926 - val_mae: 648.5926 - val_mse: 1126571.2500 - learning_rate: 0.0010
# Epoch 47/1000
# 92/93 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 398.5779 - mae: 398.5779 - mse: 723664.5625
# Epoch 47: val_loss did not improve from 628.45392
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - loss: 398.7548 - mae: 398.7548 - mse: 723753.6250 - val_loss: 1205.0991 - val_mae: 1205.0991 - val_mse: 2472838.0000 - learning_rate: 0.0010
# Epoch 48/1000
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 384.6122 - mae: 384.6122 - mse: 636895.9375
# Epoch 48: val_loss did not improve from 628.45392
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - loss: 384.7193 - mae: 384.7193 - mse: 637563.0625 - val_loss: 801.6963 - val_mae: 801.6963 - val_mse: 1464728.5000 - learning_rate: 0.0010
# Epoch 49/1000
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 372.5450 - mae: 372.5450 - mse: 613104.8750
# Epoch 49: val_loss did not improve from 628.45392
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - loss: 372.6843 - mae: 372.6843 - mse: 613455.1250 - val_loss: 880.7712 - val_mae: 880.7712 - val_mse: 1557308.1250 - learning_rate: 0.0010
# Epoch 50/1000
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 356.7070 - mae: 356.7070 - mse: 558924.6875
# Epoch 50: val_loss did not improve from 628.45392
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - loss: 356.9327 - mae: 356.9327 - mse: 559752.2500 - val_loss: 861.0591 - val_mae: 861.0591 - val_mse: 1569885.1250 - learning_rate: 0.0010
# Epoch 51/1000
# 92/93 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 399.8730 - mae: 399.8730 - mse: 637277.1875
# Epoch 51: val_loss improved from 628.45392 to 621.98291, saving model to Model/Model_N_BEATS/best_model.keras
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 4s 48ms/step - loss: 399.4945 - mae: 399.4945 - mse: 637197.6250 - val_loss: 621.9829 - val_mae: 621.9829 - val_mse: 1080812.1250 - learning_rate: 0.0010
# Epoch 52/1000
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 388.0219 - mae: 388.0219 - mse: 680584.9375
# Epoch 52: val_loss did not improve from 621.98291
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - loss: 387.9554 - mae: 387.9554 - mse: 680204.1875 - val_loss: 1015.3023 - val_mae: 1015.3023 - val_mse: 1925584.1250 - learning_rate: 0.0010
# Epoch 53/1000
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 405.5726 - mae: 405.5726 - mse: 729060.6875
# Epoch 53: val_loss did not improve from 621.98291
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - loss: 405.4893 - mae: 405.4893 - mse: 728838.8125 - val_loss: 843.3422 - val_mae: 843.3422 - val_mse: 1455360.0000 - learning_rate: 0.0010
# Epoch 54/1000
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 384.7407 - mae: 384.7407 - mse: 669512.6250
# Epoch 54: val_loss did not improve from 621.98291
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - loss: 384.8880 - mae: 384.8880 - mse: 669682.5000 - val_loss: 678.6243 - val_mae: 678.6243 - val_mse: 1168381.2500 - learning_rate: 0.0010
# Epoch 55/1000
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 378.7265 - mae: 378.7265 - mse: 645183.5625
# Epoch 55: val_loss improved from 621.98291 to 618.98608, saving model to Model/Model_N_BEATS/best_model.keras
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 4s 47ms/step - loss: 378.9524 - mae: 378.9524 - mse: 645904.9375 - val_loss: 618.9861 - val_mae: 618.9861 - val_mse: 1059240.5000 - learning_rate: 0.0010
# Epoch 56/1000
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 364.3299 - mae: 364.3299 - mse: 573141.3750
# Epoch 56: val_loss improved from 618.98608 to 612.27979, saving model to Model/Model_N_BEATS/best_model.keras
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 4s 48ms/step - loss: 364.4386 - mae: 364.4386 - mse: 573758.3750 - val_loss: 612.2798 - val_mae: 612.2798 - val_mse: 1024510.6250 - learning_rate: 0.0010
# Epoch 57/1000
# 92/93 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 375.6407 - mae: 375.6407 - mse: 635028.1875
# Epoch 57: val_loss did not improve from 612.27979
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - loss: 376.2697 - mae: 376.2697 - mse: 636524.5625 - val_loss: 1471.7740 - val_mae: 1471.7740 - val_mse: 3315561.5000 - learning_rate: 0.0010
# Epoch 58/1000
# 92/93 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 395.6403 - mae: 395.6403 - mse: 711946.1250
# Epoch 58: val_loss did not improve from 612.27979
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - loss: 395.1641 - mae: 395.1641 - mse: 710570.8125 - val_loss: 907.9647 - val_mae: 907.9647 - val_mse: 1625311.0000 - learning_rate: 0.0010
# Epoch 59/1000
# 92/93 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 366.3707 - mae: 366.3707 - mse: 588499.6875
# Epoch 59: val_loss did not improve from 612.27979
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - loss: 366.6603 - mae: 366.6603 - mse: 589658.0000 - val_loss: 658.4847 - val_mae: 658.4847 - val_mse: 1131581.6250 - learning_rate: 0.0010
# Epoch 60/1000
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 370.3667 - mae: 370.3667 - mse: 590514.1875
# Epoch 60: val_loss did not improve from 612.27979
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - loss: 370.3790 - mae: 370.3790 - mse: 590934.5000 - val_loss: 692.0597 - val_mae: 692.0597 - val_mse: 1187174.7500 - learning_rate: 0.0010
# Epoch 61/1000
# 92/93 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 373.6978 - mae: 373.6978 - mse: 659175.3750
# Epoch 61: val_loss did not improve from 612.27979
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - loss: 373.7366 - mae: 373.7366 - mse: 658950.4375 - val_loss: 789.6987 - val_mae: 789.6987 - val_mse: 1418249.6250 - learning_rate: 0.0010
# Epoch 62/1000
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 373.2310 - mae: 373.2310 - mse: 636230.0625
# Epoch 62: val_loss did not improve from 612.27979
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - loss: 373.2263 - mae: 373.2263 - mse: 636328.5625 - val_loss: 1159.1876 - val_mae: 1159.1876 - val_mse: 2345159.5000 - learning_rate: 0.0010
# Epoch 63/1000
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 385.6657 - mae: 385.6657 - mse: 692837.6250
# Epoch 63: val_loss did not improve from 612.27979
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 3s 32ms/step - loss: 385.5867 - mae: 385.5867 - mse: 692415.9375 - val_loss: 844.8696 - val_mae: 844.8696 - val_mse: 1661774.2500 - learning_rate: 0.0010
# Epoch 64/1000
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 379.9782 - mae: 379.9782 - mse: 666863.5625
# Epoch 64: val_loss did not improve from 612.27979
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - loss: 379.8281 - mae: 379.8281 - mse: 666486.0000 - val_loss: 708.1788 - val_mae: 708.1788 - val_mse: 1268348.5000 - learning_rate: 0.0010
# Epoch 65/1000
# 92/93 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 361.4188 - mae: 361.4188 - mse: 602782.1250
# Epoch 65: val_loss did not improve from 612.27979
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - loss: 361.6283 - mae: 361.6283 - mse: 603640.6875 - val_loss: 651.6662 - val_mae: 651.6662 - val_mse: 1113676.3750 - learning_rate: 0.0010
# Epoch 66/1000
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 362.6282 - mae: 362.6282 - mse: 599270.3750
# Epoch 66: val_loss did not improve from 612.27979
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - loss: 362.5466 - mae: 362.5466 - mse: 599059.8125 - val_loss: 736.4253 - val_mae: 736.4253 - val_mse: 1288197.7500 - learning_rate: 0.0010
# Epoch 67/1000
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 356.0345 - mae: 356.0345 - mse: 564705.9375
# Epoch 67: val_loss did not improve from 612.27979
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - loss: 356.0732 - mae: 356.0732 - mse: 565026.0625 - val_loss: 769.3868 - val_mae: 769.3868 - val_mse: 1297035.8750 - learning_rate: 0.0010
# Epoch 68/1000
# 92/93 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 364.2718 - mae: 364.2718 - mse: 637341.3750
# Epoch 68: val_loss did not improve from 612.27979
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - loss: 364.5096 - mae: 364.5096 - mse: 637993.2500 - val_loss: 678.0697 - val_mae: 678.0697 - val_mse: 1194313.8750 - learning_rate: 0.0010
# Epoch 69/1000
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 398.3387 - mae: 398.3387 - mse: 721535.1250
# Epoch 69: val_loss did not improve from 612.27979
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - loss: 398.0369 - mae: 398.0369 - mse: 720429.2500 - val_loss: 670.0953 - val_mae: 670.0953 - val_mse: 1163075.0000 - learning_rate: 0.0010
# Epoch 70/1000
# 92/93 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 373.6166 - mae: 373.6166 - mse: 646423.1875
# Epoch 70: val_loss did not improve from 612.27979
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - loss: 374.2553 - mae: 374.2553 - mse: 649199.0625 - val_loss: 651.4917 - val_mae: 651.4917 - val_mse: 1161926.5000 - learning_rate: 0.0010
# Epoch 71/1000
# 92/93 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 399.0132 - mae: 399.0132 - mse: 710751.6250
# Epoch 71: val_loss did not improve from 612.27979
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - loss: 398.8321 - mae: 398.8321 - mse: 710325.3125 - val_loss: 666.0768 - val_mae: 666.0768 - val_mse: 1143460.7500 - learning_rate: 0.0010
# Epoch 72/1000
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 357.8154 - mae: 357.8154 - mse: 605783.8750
# Epoch 72: val_loss did not improve from 612.27979
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - loss: 357.8487 - mae: 357.8487 - mse: 605640.4375 - val_loss: 994.3474 - val_mae: 994.3474 - val_mse: 1918131.1250 - learning_rate: 0.0010
# Epoch 73/1000
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 375.3268 - mae: 375.3268 - mse: 581526.5625
# Epoch 73: val_loss did not improve from 612.27979
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - loss: 375.4426 - mae: 375.4426 - mse: 582165.3125 - val_loss: 659.1335 - val_mae: 659.1335 - val_mse: 1169020.5000 - learning_rate: 0.0010
# Epoch 74/1000
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 386.8178 - mae: 386.8178 - mse: 706333.5000
# Epoch 74: val_loss did not improve from 612.27979
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - loss: 386.6954 - mae: 386.6954 - mse: 705830.4375 - val_loss: 677.8975 - val_mae: 677.8975 - val_mse: 1112329.0000 - learning_rate: 0.0010
# Epoch 75/1000
# 91/93 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 374.9925 - mae: 374.9925 - mse: 654233.6250
# Epoch 75: val_loss did not improve from 612.27979
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - loss: 374.7624 - mae: 374.7624 - mse: 653553.3750 - val_loss: 813.4191 - val_mae: 813.4191 - val_mse: 1389023.0000 - learning_rate: 0.0010
# Epoch 76/1000
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 454.8374 - mae: 454.8374 - mse: 1046164.1875
# Epoch 76: val_loss did not improve from 612.27979
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - loss: 454.5774 - mae: 454.5774 - mse: 1044352.0625 - val_loss: 763.1617 - val_mae: 763.1617 - val_mse: 1307522.0000 - learning_rate: 0.0010
# Epoch 77/1000
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 359.8105 - mae: 359.8105 - mse: 613740.4375
# Epoch 77: val_loss did not improve from 612.27979
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - loss: 359.7693 - mae: 359.7693 - mse: 613378.1875 - val_loss: 786.4619 - val_mae: 786.4619 - val_mse: 1437006.1250 - learning_rate: 0.0010
# Epoch 78/1000
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 396.0810 - mae: 396.0810 - mse: 751712.5625
# Epoch 78: val_loss did not improve from 612.27979
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - loss: 395.9207 - mae: 395.9207 - mse: 750916.2500 - val_loss: 733.7014 - val_mae: 733.7014 - val_mse: 1224252.5000 - learning_rate: 0.0010
# Epoch 79/1000
# 92/93 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 360.8049 - mae: 360.8049 - mse: 556290.1250
# Epoch 79: val_loss did not improve from 612.27979
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - loss: 360.7811 - mae: 360.7811 - mse: 556863.6875 - val_loss: 1288.2354 - val_mae: 1288.2354 - val_mse: 2641284.2500 - learning_rate: 0.0010
# Epoch 80/1000
# 92/93 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 372.6706 - mae: 372.6706 - mse: 619835.8125
# Epoch 80: val_loss did not improve from 612.27979
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - loss: 372.4617 - mae: 372.4617 - mse: 618811.5000 - val_loss: 828.9604 - val_mae: 828.9604 - val_mse: 1394229.2500 - learning_rate: 0.0010
# Epoch 81/1000
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 382.1700 - mae: 382.1700 - mse: 726337.0000
# Epoch 81: val_loss did not improve from 612.27979
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - loss: 382.0224 - mae: 382.0224 - mse: 725402.8750 - val_loss: 969.0429 - val_mae: 969.0429 - val_mse: 1972151.2500 - learning_rate: 0.0010
# Epoch 82/1000
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 381.2190 - mae: 381.2190 - mse: 595051.5000
# Epoch 82: val_loss did not improve from 612.27979
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - loss: 381.2299 - mae: 381.2299 - mse: 595574.8125 - val_loss: 718.9072 - val_mae: 718.9072 - val_mse: 1273239.0000 - learning_rate: 0.0010
# Epoch 83/1000
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 375.6219 - mae: 375.6219 - mse: 640448.6250
# Epoch 83: val_loss did not improve from 612.27979
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - loss: 375.4789 - mae: 375.4789 - mse: 640070.7500 - val_loss: 630.7511 - val_mae: 630.7511 - val_mse: 1093013.6250 - learning_rate: 0.0010
# Epoch 84/1000
# 91/93 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 361.5186 - mae: 361.5186 - mse: 614584.8125
# Epoch 84: val_loss did not improve from 612.27979
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - loss: 362.3175 - mae: 362.3175 - mse: 616175.3750 - val_loss: 696.2742 - val_mae: 696.2742 - val_mse: 1283701.0000 - learning_rate: 0.0010
# Epoch 85/1000
# 91/93 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 359.6935 - mae: 359.6935 - mse: 641453.5625
# Epoch 85: val_loss did not improve from 612.27979
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 360.0366 - mae: 360.0366 - mse: 641344.5625 - val_loss: 721.5125 - val_mae: 721.5125 - val_mse: 1307465.7500 - learning_rate: 0.0010
# Epoch 86/1000
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 350.2795 - mae: 350.2795 - mse: 566503.4375
# Epoch 86: val_loss did not improve from 612.27979
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - loss: 350.4246 - mae: 350.4246 - mse: 566933.3125 - val_loss: 662.0247 - val_mae: 662.0247 - val_mse: 1100505.1250 - learning_rate: 0.0010
# Epoch 87/1000
# 91/93 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 340.5040 - mae: 340.5040 - mse: 534120.1875
# Epoch 87: val_loss did not improve from 612.27979
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 341.6120 - mae: 341.6120 - mse: 537546.7500 - val_loss: 695.8316 - val_mae: 695.8316 - val_mse: 1225095.3750 - learning_rate: 0.0010
# Epoch 88/1000
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 371.1179 - mae: 371.1179 - mse: 645387.3125
# Epoch 88: val_loss did not improve from 612.27979
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - loss: 371.1938 - mae: 371.1938 - mse: 645613.5625 - val_loss: 856.2462 - val_mae: 856.2462 - val_mse: 1502595.2500 - learning_rate: 0.0010
# Epoch 89/1000
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 364.6502 - mae: 364.6502 - mse: 586272.1250
# Epoch 89: val_loss did not improve from 612.27979
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - loss: 364.5780 - mae: 364.5780 - mse: 586325.6250 - val_loss: 773.1182 - val_mae: 773.1182 - val_mse: 1364088.2500 - learning_rate: 0.0010
# Epoch 90/1000
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 334.6557 - mae: 334.6557 - mse: 501838.3438
# Epoch 90: val_loss did not improve from 612.27979
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - loss: 334.8640 - mae: 334.8640 - mse: 502829.8438 - val_loss: 867.6727 - val_mae: 867.6727 - val_mse: 1604730.8750 - learning_rate: 0.0010
# Epoch 91/1000
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 384.6203 - mae: 384.6203 - mse: 664334.1250
# Epoch 91: val_loss did not improve from 612.27979
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - loss: 384.3820 - mae: 384.3820 - mse: 663834.4375 - val_loss: 724.3058 - val_mae: 724.3058 - val_mse: 1248618.5000 - learning_rate: 0.0010
# Epoch 92/1000
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 348.5826 - mae: 348.5826 - mse: 559283.1875
# Epoch 92: val_loss did not improve from 612.27979
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - loss: 348.7173 - mae: 348.7173 - mse: 559511.2500 - val_loss: 849.0619 - val_mae: 849.0619 - val_mse: 1505860.7500 - learning_rate: 0.0010
# Epoch 93/1000
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 345.0264 - mae: 345.0264 - mse: 497147.5312
# Epoch 93: val_loss did not improve from 612.27979
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - loss: 345.1301 - mae: 345.1301 - mse: 498003.2812 - val_loss: 741.5914 - val_mae: 741.5914 - val_mse: 1212726.5000 - learning_rate: 0.0010
# Epoch 94/1000
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 367.3498 - mae: 367.3498 - mse: 571976.2500
# Epoch 94: val_loss did not improve from 612.27979
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - loss: 367.3112 - mae: 367.3112 - mse: 572183.4375 - val_loss: 744.4498 - val_mae: 744.4498 - val_mse: 1395425.2500 - learning_rate: 0.0010
# Epoch 95/1000
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 400.5812 - mae: 400.5812 - mse: 742494.3125
# Epoch 95: val_loss did not improve from 612.27979
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - loss: 400.3249 - mae: 400.3249 - mse: 741545.2500 - val_loss: 764.7517 - val_mae: 764.7517 - val_mse: 1406757.7500 - learning_rate: 0.0010
# Epoch 96/1000
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 364.8795 - mae: 364.8795 - mse: 601675.0625
# Epoch 96: val_loss did not improve from 612.27979
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - loss: 364.9413 - mae: 364.9413 - mse: 601796.3750 - val_loss: 770.5639 - val_mae: 770.5639 - val_mse: 1287314.2500 - learning_rate: 0.0010
# Epoch 97/1000
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 335.4348 - mae: 335.4348 - mse: 494594.8125
# Epoch 97: val_loss did not improve from 612.27979
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - loss: 335.5498 - mae: 335.5498 - mse: 494960.9062 - val_loss: 823.3318 - val_mae: 823.3318 - val_mse: 1525824.2500 - learning_rate: 0.0010
# Epoch 98/1000
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 364.7777 - mae: 364.7777 - mse: 599439.4375
# Epoch 98: val_loss did not improve from 612.27979
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - loss: 364.9391 - mae: 364.9391 - mse: 599907.4375 - val_loss: 705.8102 - val_mae: 705.8102 - val_mse: 1185458.5000 - learning_rate: 0.0010
# Epoch 99/1000
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 367.5002 - mae: 367.5002 - mse: 636433.1250
# Epoch 99: val_loss did not improve from 612.27979
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - loss: 367.3978 - mae: 367.3978 - mse: 636022.7500 - val_loss: 819.1334 - val_mae: 819.1334 - val_mse: 1419954.7500 - learning_rate: 0.0010
# Epoch 100/1000
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 350.1563 - mae: 350.1563 - mse: 595904.3750
# Epoch 100: val_loss did not improve from 612.27979
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - loss: 350.0840 - mae: 350.0840 - mse: 595608.5000 - val_loss: 873.9619 - val_mae: 873.9619 - val_mse: 1575667.8750 - learning_rate: 0.0010
# Epoch 101/1000
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 346.4001 - mae: 346.4001 - mse: 516737.8750
# Epoch 101: val_loss did not improve from 612.27979
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - loss: 346.5764 - mae: 346.5764 - mse: 517481.3125 - val_loss: 713.4592 - val_mae: 713.4592 - val_mse: 1263321.0000 - learning_rate: 0.0010
# Epoch 102/1000
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 348.4340 - mae: 348.4340 - mse: 575894.5625
# Epoch 102: val_loss did not improve from 612.27979
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - loss: 348.4196 - mae: 348.4196 - mse: 575772.6250 - val_loss: 682.4516 - val_mae: 682.4516 - val_mse: 1157257.8750 - learning_rate: 0.0010
# Epoch 103/1000
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 375.9153 - mae: 375.9153 - mse: 639409.4375
# Epoch 103: val_loss did not improve from 612.27979
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - loss: 375.7299 - mae: 375.7299 - mse: 638899.3750 - val_loss: 741.0140 - val_mae: 741.0140 - val_mse: 1335292.0000 - learning_rate: 0.0010
# Epoch 104/1000
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 355.3374 - mae: 355.3374 - mse: 593754.8750
# Epoch 104: val_loss did not improve from 612.27979
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - loss: 355.2544 - mae: 355.2544 - mse: 593347.8125 - val_loss: 922.4849 - val_mae: 922.4849 - val_mse: 1618821.6250 - learning_rate: 0.0010
# Epoch 105/1000
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 354.8158 - mae: 354.8158 - mse: 590721.1250
# Epoch 105: val_loss did not improve from 612.27979
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - loss: 354.7880 - mae: 354.7880 - mse: 590497.2500 - val_loss: 669.6191 - val_mae: 669.6191 - val_mse: 1192725.8750 - learning_rate: 0.0010
# Epoch 106/1000
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 337.6919 - mae: 337.6919 - mse: 578964.1250
# Epoch 106: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
#
# Epoch 106: val_loss did not improve from 612.27979
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - loss: 338.0253 - mae: 338.0253 - mse: 579650.9375 - val_loss: 824.5096 - val_mae: 824.5096 - val_mse: 1547889.7500 - learning_rate: 0.0010
# Epoch 107/1000
# 92/93 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 353.5675 - mae: 353.5675 - mse: 632604.9375
# Epoch 107: val_loss did not improve from 612.27979
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - loss: 353.0274 - mae: 353.0274 - mse: 630557.5625 - val_loss: 620.7714 - val_mae: 620.7714 - val_mse: 1060162.6250 - learning_rate: 1.0000e-04
# Epoch 108/1000
# 92/93 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 289.2073 - mae: 289.2073 - mse: 453243.6562
# Epoch 108: val_loss did not improve from 612.27979
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - loss: 289.2532 - mae: 289.2532 - mse: 452734.3125 - val_loss: 637.7188 - val_mae: 637.7188 - val_mse: 1098952.3750 - learning_rate: 1.0000e-04
# Epoch 109/1000
# 92/93 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 287.3857 - mae: 287.3857 - mse: 465802.4688
# Epoch 109: val_loss did not improve from 612.27979
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - loss: 287.0437 - mae: 287.0437 - mse: 463828.0312 - val_loss: 642.6230 - val_mae: 642.6230 - val_mse: 1106898.6250 - learning_rate: 1.0000e-04
# Epoch 110/1000
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 248.2572 - mae: 248.2572 - mse: 302172.1250
# Epoch 110: val_loss did not improve from 612.27979
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - loss: 248.3248 - mae: 248.3248 - mse: 302503.8750 - val_loss: 659.6127 - val_mae: 659.6127 - val_mse: 1140871.5000 - learning_rate: 1.0000e-04
# Epoch 111/1000
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 230.1697 - mae: 230.1697 - mse: 270064.3125
# Epoch 111: val_loss did not improve from 612.27979
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - loss: 230.2708 - mae: 230.2708 - mse: 270463.4688 - val_loss: 660.4820 - val_mae: 660.4820 - val_mse: 1155763.8750 - learning_rate: 1.0000e-04
# Epoch 112/1000
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 238.9131 - mae: 238.9131 - mse: 324556.0938
# Epoch 112: val_loss did not improve from 612.27979
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - loss: 238.7916 - mae: 238.7916 - mse: 324109.3750 - val_loss: 659.8560 - val_mae: 659.8560 - val_mse: 1137484.2500 - learning_rate: 1.0000e-04
# Epoch 113/1000
# 92/93 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 204.2814 - mae: 204.2814 - mse: 230545.9062
# Epoch 113: val_loss did not improve from 612.27979
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - loss: 204.5882 - mae: 204.5882 - mse: 231238.8125 - val_loss: 657.6105 - val_mae: 657.6105 - val_mse: 1131614.8750 - learning_rate: 1.0000e-04
# Epoch 114/1000
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 189.6694 - mae: 189.6694 - mse: 203313.4219
# Epoch 114: val_loss did not improve from 612.27979
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 3s 32ms/step - loss: 189.8530 - mae: 189.8530 - mse: 203718.4844 - val_loss: 662.5734 - val_mae: 662.5734 - val_mse: 1133714.7500 - learning_rate: 1.0000e-04
# Epoch 115/1000
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 196.7277 - mae: 196.7277 - mse: 235960.2969
# Epoch 115: val_loss did not improve from 612.27979
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - loss: 196.7846 - mae: 196.7846 - mse: 235951.6094 - val_loss: 655.1252 - val_mae: 655.1252 - val_mse: 1129045.2500 - learning_rate: 1.0000e-04
# Epoch 116/1000
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 197.2692 - mae: 197.2692 - mse: 215649.6719
# Epoch 116: val_loss did not improve from 612.27979
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - loss: 197.2649 - mae: 197.2649 - mse: 215726.1094 - val_loss: 668.5597 - val_mae: 668.5597 - val_mse: 1141902.7500 - learning_rate: 1.0000e-04
# Epoch 117/1000
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 188.1014 - mae: 188.1014 - mse: 201289.1719
# Epoch 117: val_loss did not improve from 612.27979
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - loss: 188.1006 - mae: 188.1006 - mse: 201362.5469 - val_loss: 677.5421 - val_mae: 677.5421 - val_mse: 1171654.8750 - learning_rate: 1.0000e-04
# Epoch 118/1000
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 185.5017 - mae: 185.5017 - mse: 199377.1250
# Epoch 118: val_loss did not improve from 612.27979
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - loss: 185.4916 - mae: 185.4916 - mse: 199417.3125 - val_loss: 661.6423 - val_mae: 661.6423 - val_mse: 1118436.6250 - learning_rate: 1.0000e-04
# Epoch 119/1000
# 92/93 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 173.6205 - mae: 173.6205 - mse: 168561.6094
# Epoch 119: val_loss did not improve from 612.27979
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - loss: 173.7467 - mae: 173.7467 - mse: 169093.3438 - val_loss: 671.3462 - val_mae: 671.3462 - val_mse: 1131073.3750 - learning_rate: 1.0000e-04
# Epoch 120/1000
# 91/93 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 181.4539 - mae: 181.4539 - mse: 214709.5000
# Epoch 120: val_loss did not improve from 612.27979
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - loss: 181.1184 - mae: 181.1184 - mse: 213576.7656 - val_loss: 684.6179 - val_mae: 684.6179 - val_mse: 1163874.5000 - learning_rate: 1.0000e-04
# Epoch 121/1000
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 163.2547 - mae: 163.2547 - mse: 137296.5781
# Epoch 121: val_loss did not improve from 612.27979
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - loss: 163.3166 - mae: 163.3166 - mse: 137652.6250 - val_loss: 664.2650 - val_mae: 664.2650 - val_mse: 1124050.3750 - learning_rate: 1.0000e-04
# Epoch 122/1000
# 92/93 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 158.1236 - mae: 158.1236 - mse: 148866.5469
# Epoch 122: val_loss did not improve from 612.27979
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - loss: 158.2024 - mae: 158.2024 - mse: 149105.7188 - val_loss: 659.5142 - val_mae: 659.5142 - val_mse: 1110539.2500 - learning_rate: 1.0000e-04
# Epoch 123/1000
# 92/93 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 157.5095 - mae: 157.5095 - mse: 136269.9062
# Epoch 123: val_loss did not improve from 612.27979
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - loss: 157.5341 - mae: 157.5341 - mse: 136592.9531 - val_loss: 675.6091 - val_mae: 675.6091 - val_mse: 1155615.7500 - learning_rate: 1.0000e-04
# Epoch 124/1000
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 150.1916 - mae: 150.1916 - mse: 130015.1875
# Epoch 124: val_loss did not improve from 612.27979
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - loss: 150.1855 - mae: 150.1855 - mse: 130117.7109 - val_loss: 680.1616 - val_mae: 680.1616 - val_mse: 1167548.5000 - learning_rate: 1.0000e-04
# Epoch 125/1000
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 145.9749 - mae: 145.9749 - mse: 121163.6484
# Epoch 125: val_loss did not improve from 612.27979
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - loss: 146.0084 - mae: 146.0084 - mse: 121293.4375 - val_loss: 667.7395 - val_mae: 667.7395 - val_mse: 1147293.7500 - learning_rate: 1.0000e-04
# Epoch 126/1000
# 92/93 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 154.2438 - mae: 154.2438 - mse: 137386.5156
# Epoch 126: val_loss did not improve from 612.27979
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - loss: 154.0853 - mae: 154.0853 - mse: 137177.4219 - val_loss: 672.6348 - val_mae: 672.6348 - val_mse: 1138137.8750 - learning_rate: 1.0000e-04
# Epoch 127/1000
# 92/93 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 138.5244 - mae: 138.5244 - mse: 116672.5156
# Epoch 127: val_loss did not improve from 612.27979
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - loss: 138.5446 - mae: 138.5446 - mse: 116705.2188 - val_loss: 677.2934 - val_mae: 677.2934 - val_mse: 1160133.7500 - learning_rate: 1.0000e-04
# Epoch 128/1000
# 92/93 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 131.9213 - mae: 131.9213 - mse: 94679.6328
# Epoch 128: val_loss did not improve from 612.27979
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - loss: 132.0347 - mae: 132.0347 - mse: 95100.5312 - val_loss: 668.2189 - val_mae: 668.2189 - val_mse: 1135206.6250 - learning_rate: 1.0000e-04
# Epoch 129/1000
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 131.4463 - mae: 131.4463 - mse: 101666.7656
# Epoch 129: val_loss did not improve from 612.27979
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - loss: 131.4726 - mae: 131.4726 - mse: 101737.6797 - val_loss: 668.9708 - val_mae: 668.9708 - val_mse: 1145314.3750 - learning_rate: 1.0000e-04
# Epoch 130/1000
# 92/93 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 120.2780 - mae: 120.2780 - mse: 85802.1250
# Epoch 130: val_loss did not improve from 612.27979
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - loss: 120.4053 - mae: 120.4053 - mse: 86109.1953 - val_loss: 686.8706 - val_mae: 686.8706 - val_mse: 1175089.2500 - learning_rate: 1.0000e-04
# Epoch 131/1000
# 92/93 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 132.5947 - mae: 132.5947 - mse: 100385.4922
# Epoch 131: val_loss did not improve from 612.27979
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - loss: 132.4602 - mae: 132.4602 - mse: 100355.0312 - val_loss: 675.4552 - val_mae: 675.4552 - val_mse: 1164834.0000 - learning_rate: 1.0000e-04
# Epoch 132/1000
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 112.3311 - mae: 112.3311 - mse: 74141.9062
# Epoch 132: val_loss did not improve from 612.27979
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - loss: 112.4112 - mae: 112.4112 - mse: 74333.8828 - val_loss: 692.2665 - val_mae: 692.2665 - val_mse: 1200962.5000 - learning_rate: 1.0000e-04
# Epoch 133/1000
# 92/93 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 120.8937 - mae: 120.8937 - mse: 90642.7188
# Epoch 133: val_loss did not improve from 612.27979
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - loss: 120.8621 - mae: 120.8621 - mse: 90596.7500 - val_loss: 684.2586 - val_mae: 684.2586 - val_mse: 1161826.1250 - learning_rate: 1.0000e-04
# Epoch 134/1000
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 127.9464 - mae: 127.9464 - mse: 104512.7500
# Epoch 134: val_loss did not improve from 612.27979
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - loss: 127.8397 - mae: 127.8397 - mse: 104281.4766 - val_loss: 675.4540 - val_mae: 675.4540 - val_mse: 1146615.5000 - learning_rate: 1.0000e-04
# Epoch 135/1000
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 119.8166 - mae: 119.8166 - mse: 90698.4922
# Epoch 135: val_loss did not improve from 612.27979
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - loss: 119.7704 - mae: 119.7704 - mse: 90555.9062 - val_loss: 676.9337 - val_mae: 676.9337 - val_mse: 1157617.3750 - learning_rate: 1.0000e-04
# Epoch 136/1000
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 111.3545 - mae: 111.3545 - mse: 86096.5156
# Epoch 136: val_loss did not improve from 612.27979
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - loss: 111.3652 - mae: 111.3652 - mse: 85983.7188 - val_loss: 686.6775 - val_mae: 686.6775 - val_mse: 1195101.6250 - learning_rate: 1.0000e-04
# Epoch 137/1000
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 99.1143 - mae: 99.1143 - mse: 47857.4727
# Epoch 137: val_loss did not improve from 612.27979
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - loss: 99.2306 - mae: 99.2306 - mse: 48109.9102 - val_loss: 699.8605 - val_mae: 699.8605 - val_mse: 1216741.7500 - learning_rate: 1.0000e-04
# Epoch 138/1000
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 102.6198 - mae: 102.6198 - mse: 58560.5000
# Epoch 138: val_loss did not improve from 612.27979
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - loss: 102.6375 - mae: 102.6375 - mse: 58643.2461 - val_loss: 674.0692 - val_mae: 674.0692 - val_mse: 1176350.7500 - learning_rate: 1.0000e-04
# Epoch 139/1000
# 92/93 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 103.0980 - mae: 103.0980 - mse: 65027.7109
# Epoch 139: val_loss did not improve from 612.27979
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - loss: 103.1387 - mae: 103.1387 - mse: 65037.7734 - val_loss: 673.1556 - val_mae: 673.1556 - val_mse: 1162024.0000 - learning_rate: 1.0000e-04
# Epoch 140/1000
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 104.5173 - mae: 104.5173 - mse: 57972.1016
# Epoch 140: val_loss did not improve from 612.27979
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - loss: 104.4822 - mae: 104.4822 - mse: 58017.2578 - val_loss: 693.9170 - val_mae: 693.9170 - val_mse: 1198689.2500 - learning_rate: 1.0000e-04
# Epoch 141/1000
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 92.6534 - mae: 92.6534 - mse: 46399.9453
# Epoch 141: val_loss did not improve from 612.27979
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - loss: 92.7107 - mae: 92.7107 - mse: 46509.0547 - val_loss: 678.0491 - val_mae: 678.0491 - val_mse: 1178004.1250 - learning_rate: 1.0000e-04
# Epoch 142/1000
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 94.2582 - mae: 94.2582 - mse: 54573.7383
# Epoch 142: val_loss did not improve from 612.27979
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - loss: 94.2860 - mae: 94.2860 - mse: 54581.8398 - val_loss: 692.3997 - val_mae: 692.3997 - val_mse: 1201423.5000 - learning_rate: 1.0000e-04
# Epoch 143/1000
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 96.5439 - mae: 96.5439 - mse: 46988.7656
# Epoch 143: val_loss did not improve from 612.27979
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 3s 32ms/step - loss: 96.5527 - mae: 96.5527 - mse: 47071.5586 - val_loss: 694.4626 - val_mae: 694.4626 - val_mse: 1204882.3750 - learning_rate: 1.0000e-04
# Epoch 144/1000
# 92/93 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 99.5491 - mae: 99.5491 - mse: 62090.9688
# Epoch 144: val_loss did not improve from 612.27979
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - loss: 99.4563 - mae: 99.4563 - mse: 61872.4102 - val_loss: 707.7555 - val_mae: 707.7555 - val_mse: 1246053.8750 - learning_rate: 1.0000e-04
# Epoch 145/1000
# 91/93 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 92.0867 - mae: 92.0867 - mse: 47608.0977
# Epoch 145: val_loss did not improve from 612.27979
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - loss: 92.1918 - mae: 92.1918 - mse: 47711.0586 - val_loss: 694.0417 - val_mae: 694.0417 - val_mse: 1203571.0000 - learning_rate: 1.0000e-04
# Epoch 146/1000
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 84.1648 - mae: 84.1648 - mse: 40081.0625
# Epoch 146: val_loss did not improve from 612.27979
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - loss: 84.2197 - mae: 84.2197 - mse: 40150.9258 - val_loss: 691.1810 - val_mae: 691.1810 - val_mse: 1198932.1250 - learning_rate: 1.0000e-04
# Epoch 147/1000
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 91.8246 - mae: 91.8246 - mse: 55005.5117
# Epoch 147: val_loss did not improve from 612.27979
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - loss: 91.8268 - mae: 91.8268 - mse: 54926.2109 - val_loss: 688.6805 - val_mae: 688.6805 - val_mse: 1192763.5000 - learning_rate: 1.0000e-04
# Epoch 148/1000
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 90.8777 - mae: 90.8777 - mse: 44007.2109
# Epoch 148: val_loss did not improve from 612.27979
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - loss: 90.8981 - mae: 90.8981 - mse: 44036.3984 - val_loss: 691.8891 - val_mae: 691.8891 - val_mse: 1210942.2500 - learning_rate: 1.0000e-04
# Epoch 149/1000
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 89.5211 - mae: 89.5211 - mse: 41878.6719
# Epoch 149: val_loss did not improve from 612.27979
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - loss: 89.5287 - mae: 89.5287 - mse: 41900.9844 - val_loss: 697.6694 - val_mae: 697.6694 - val_mse: 1223164.0000 - learning_rate: 1.0000e-04
# Epoch 150/1000
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 87.8190 - mae: 87.8190 - mse: 47135.0430
# Epoch 150: val_loss did not improve from 612.27979
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - loss: 87.7847 - mae: 87.7847 - mse: 47069.9766 - val_loss: 699.5403 - val_mae: 699.5403 - val_mse: 1220216.6250 - learning_rate: 1.0000e-04
# Epoch 151/1000
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 83.8063 - mae: 83.8063 - mse: 36768.3398
# Epoch 151: val_loss did not improve from 612.27979
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - loss: 83.7864 - mae: 83.7864 - mse: 36778.8477 - val_loss: 686.1799 - val_mae: 686.1799 - val_mse: 1193368.3750 - learning_rate: 1.0000e-04
# Epoch 152/1000
# 92/93 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 86.4671 - mae: 86.4671 - mse: 45054.7109
# Epoch 152: val_loss did not improve from 612.27979
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 86.4646 - mae: 86.4646 - mse: 44927.2852 - val_loss: 697.9425 - val_mae: 697.9425 - val_mse: 1237081.5000 - learning_rate: 1.0000e-04
# Epoch 153/1000
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 80.6462 - mae: 80.6462 - mse: 42266.2969
# Epoch 153: val_loss did not improve from 612.27979
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 80.6575 - mae: 80.6575 - mse: 42212.9961 - val_loss: 697.2657 - val_mae: 697.2657 - val_mse: 1233632.0000 - learning_rate: 1.0000e-04
# Epoch 154/1000
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 75.8051 - mae: 75.8051 - mse: 27697.2930
# Epoch 154: val_loss did not improve from 612.27979
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - loss: 75.8368 - mae: 75.8368 - mse: 27777.2754 - val_loss: 705.1823 - val_mae: 705.1823 - val_mse: 1244449.5000 - learning_rate: 1.0000e-04
# Epoch 155/1000
# 92/93 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 84.2253 - mae: 84.2253 - mse: 39592.9219
# Epoch 155: val_loss did not improve from 612.27979
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - loss: 84.1026 - mae: 84.1026 - mse: 39466.3789 - val_loss: 692.0265 - val_mae: 692.0265 - val_mse: 1197751.7500 - learning_rate: 1.0000e-04
# Epoch 156/1000
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 74.9536 - mae: 74.9536 - mse: 34859.6211
# Epoch 156: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
#
# Epoch 156: val_loss did not improve from 612.27979
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - loss: 74.9624 - mae: 74.9624 - mse: 34838.5977 - val_loss: 700.3300 - val_mae: 700.3300 - val_mse: 1234785.6250 - learning_rate: 1.0000e-04

# %%
def mean_absolute_scaled_error(y_true, y_pred, seasonality=1):
    mae = np.mean(np.abs(y_true - y_pred))
    naive_forecast = y_true[:-seasonality]
    naive_mae = np.mean(np.abs(naive_forecast - y_true[seasonality:]))
    mase = mae / naive_mae
    return mase

def evaluate_preds(y_true, y_pred):
  # Make sure float32 (for metric calculations)
  y_true = tf.cast(y_true, dtype=tf.float32)
  y_pred = tf.cast(y_pred, dtype=tf.float32)

  # Calculate various metrics
  mae = tf.keras.metrics.mean_absolute_error(y_true, y_pred)
  mse = tf.keras.metrics.mean_squared_error(y_true, y_pred)
  rmse = tf.sqrt(mse)
  huber_loss = tf.keras.losses.Huber()(y_true, y_pred)
  mase = mean_absolute_scaled_error(y_true.numpy(), y_pred.numpy(),seasonality=1)

  # Account for different sized metrics (for longer horizons, reduce to single number)
  if mae.ndim > 0: # if mae isn't already a scalar, reduce it to one by aggregating tensors to mean
    mae = tf.reduce_mean(mae)
    mse = tf.reduce_mean(mse)
    rmse = tf.reduce_mean(rmse)
    huber_loss = tf.reduce_mean(huber_loss)
    mase = tf.reduce_mean(mase)

  print("For mae, mse, rmse and hubber : lower value is better.\nmase :- A scaled eror is >1 if the forecast is worse than the naive and <1 if the forecast is better that the naive.")
  print(f"""
    "mae": {mae.numpy()},
    "mse": {mse.numpy()},
    "rmse": {rmse.numpy()},
    "huber_loss": {huber_loss.numpy()},
    "mase": {mase}
    """)
  return {
        "mae": mae.numpy(),
        "mse": mse.numpy(),
        "rmse": rmse.numpy(),
        "huber_loss": huber_loss.numpy(),
        "mase": mase.numpy()
    }

# %%
forecast  = N_BEATS_MODEL.predict(feature)
preds =(forecast)
# labels.shape, feature

# %%
evaluate_preds(y_true= labels, y_pred= preds)

# %%
# model.save('model_11_multivariate_parameter_1_500.h5')

# %%
N_BEATS_MODEL.save('trained_model_11111.h5')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 N_BEATS_MODEL.save('trained_model_11111.h5')
#
# File /opt/conda/lib/python3.10/site-packages/keras/src/utils/traceback_utils.py:122, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#     120     # To get the full stack trace, call:
#     121     # `keras.config.disable_traceback_filtering()`
# --> 122     raise e.with_traceback(filtered_tb) from None
#     123 finally:
#     124     del filtered_tb
#
# File /opt/conda/lib/python3.10/site-packages/h5py/_hl/group.py:183, in Group.create_dataset(self, name, shape, dtype, data, **kwds)
#     180         parent_path, name = name.rsplit(b'/', 1)
#     181         group = self.require_group(parent_path)
# --> 183 dsid = dataset.make_new_dset(group, shape, dtype, data, name, **kwds)
#     184 dset = dataset.Dataset(dsid)
#     185 return dset
#
# File /opt/conda/lib/python3.10/site-packages/h5py/_hl/dataset.py:163, in make_new_dset(parent, shape, dtype, data, name, chunks, compression, shuffle, fletcher32, maxshape, compression_opts, fillvalue, scaleoffset, track_times, external, track_order, dcpl, dapl, efile_prefix, virtual_prefix, allow_unknown_filter, rdcc_nslots, rdcc_nbytes, rdcc_w0)
#     160 else:
#     161     sid = h5s.create_simple(shape, maxshape)
# --> 163 dset_id = h5d.create(parent.id, name, tid, sid, dcpl=dcpl, dapl=dapl)
#     165 if (data is not None) and (not isinstance(data, Empty)):
#     166     dset_id.write(h5s.ALL, h5s.ALL, data)
#
# File h5py/_objects.pyx:54, in h5py._objects.with_phil.wrapper()
#
# File h5py/_objects.pyx:55, in h5py._objects.with_phil.wrapper()
#
# File h5py/h5d.pyx:137, in h5py.h5d.create()
#
# ValueError: Unable to synchronously create dataset (name already exists)

# %%
import os

# Get the current working directory
current_directory = os.getcwd()
print("Current working directory:", current_directory)

# List the contents of the working directory
contents = os.listdir(current_directory)
print("Contents of the working directory:", contents)

# Change directory to /kaggle/working/
os.chdir('/kaggle/working/')

# Get the current working directory (should be /kaggle/working/)
new_directory = os.getcwd()
print("New working directory:", new_directory)

# List the contents of the new working directory
new_contents = os.listdir(new_directory)
print("Contents of the new working directory:", new_contents)
# Out:
# Current working directory: /kaggle/working
# Contents of the working directory: ['.virtual_documents', 'Model', 'trained_model.h5', 'trained_model_11111.h5']
# New working directory: /kaggle/working
# Contents of the new working directory: ['.virtual_documents', 'Model', 'trained_model.h5', 'trained_model_11111.h5']

# %%
pip list
# Out:
# Package                                  Version
# ---------------------------------------- -------------------
# absl-py                                  1.4.0
# accelerate                               0.29.3
# access                                   1.1.9
# affine                                   2.4.0
# aiobotocore                              2.12.3
# aiofiles                                 22.1.0
# aiohttp                                  3.9.1
# aiohttp-cors                             0.7.0
# aioitertools                             0.11.0
# aiorwlock                                1.3.0
# aiosignal                                1.3.1
# aiosqlite                                0.19.0
# albumentations                           1.4.0
# alembic                                  1.13.1
# altair                                   5.3.0
# annotated-types                          0.6.0
# annoy                                    1.17.3
# anyio                                    4.2.0
# apache-beam                              2.46.0
# aplus                                    0.11.0
# appdirs                                  1.4.4
# archspec                                 0.2.3
# argon2-cffi                              23.1.0
# argon2-cffi-bindings                     21.2.0
# array-record                             0.5.0
# arrow                                    1.3.0
# arviz                                    0.18.0
# astroid                                  3.1.0
# astropy                                  6.0.1
# astropy-iers-data                        0.2024.4.15.2.45.49
# asttokens                                2.4.1
# astunparse                               1.6.3
# async-lru                                2.0.4
# async-timeout                            4.0.3
# attrs                                    23.2.0
# audioread                                3.0.1
# autopep8                                 2.0.4
# Babel                                    2.14.0
# backoff                                  2.2.1
# bayesian-optimization                    1.4.3
# beatrix_jupyterlab                       2023.128.151533
# beautifulsoup4                           4.12.2
# blake3                                   0.2.1
# bleach                                   6.1.0
# blessed                                  1.20.0
# blinker                                  1.7.0
# blis                                     0.7.10
# blosc2                                   2.6.2
# bokeh                                    3.4.1
# boltons                                  23.1.1
# Boruta                                   0.3
# boto3                                    1.26.100
# botocore                                 1.34.69
# bq_helper                                0.4.1
# bqplot                                   0.12.43
# branca                                   0.7.1
# brewer2mpl                               1.4.1
# Brotli                                   1.0.9
# brotlipy                                 0.7.0
# cached-property                          1.5.2
# cachetools                               4.2.4
# Cartopy                                  0.23.0
# catalogue                                2.0.10
# catalyst                                 22.4
# catboost                                 1.2.3
# category-encoders                        2.6.3
# certifi                                  2024.2.2
# cesium                                   0.12.1
# cffi                                     1.16.0
# charset-normalizer                       3.3.2
# chex                                     0.1.86
# cleverhans                               4.0.0
# click                                    8.1.7
# click-plugins                            1.1.1
# cligj                                    0.7.2
# cloud-tpu-client                         0.10
# cloud-tpu-profiler                       2.4.0
# cloudpathlib                             0.16.0
# cloudpickle                              2.2.1
# cmdstanpy                                1.2.2
# colorama                                 0.4.6
# colorcet                                 3.1.0
# colorful                                 0.5.6
# colorlog                                 6.8.2
# colorlover                               0.3.0
# comm                                     0.2.1
# conda                                    23.7.4
# conda-libmamba-solver                    23.7.0
# conda-package-handling                   2.2.0
# conda_package_streaming                  0.9.0
# confection                               0.1.4
# contextily                               1.6.0
# contourpy                                1.2.0
# convertdate                              2.4.0
# crcmod                                   1.7
# cryptography                             41.0.7
# cuda-python                              12.4.0
# cudf                                     23.8.0
# cufflinks                                0.17.3
# cuml                                     23.8.0
# cupy                                     13.0.0
# CVXcanon                                 0.1.2
# cycler                                   0.12.1
# cymem                                    2.0.8
# Cython                                   3.0.8
# cytoolz                                  0.12.3
# daal                                     2024.3.0
# daal4py                                  2024.3.0
# dacite                                   1.8.1
# dask                                     2024.4.1
# dask-cuda                                23.8.0
# dask-cudf                                23.8.0
# dask-expr                                1.0.11
# dataclasses-json                         0.6.4
# dataproc_jupyter_plugin                  0.1.66
# datasets                                 2.18.0
# datashader                               0.16.0
# datatile                                 1.0.3
# db-dtypes                                1.2.0
# deap                                     1.4.1
# debugpy                                  1.8.0
# decorator                                5.1.1
# deepdiff                                 7.0.1
# defusedxml                               0.7.1
# Deprecated                               1.2.14
# deprecation                              2.1.0
# descartes                                1.1.0
# dill                                     0.3.8
# dipy                                     1.9.0
# distlib                                  0.3.8
# distributed                              2023.7.1
# distro                                   1.9.0
# dm-tree                                  0.1.8
# docker                                   7.0.0
# docker-pycreds                           0.4.0
# docopt                                   0.6.2
# docstring-parser                         0.15
# docstring-to-markdown                    0.15
# docutils                                 0.21.1
# earthengine-api                          0.1.399
# easydict                                 1.13
# easyocr                                  1.7.1
# ecos                                     2.0.13
# eli5                                     0.13.0
# emoji                                    2.11.0
# en-core-web-lg                           3.7.1
# en-core-web-sm                           3.7.1
# entrypoints                              0.4
# ephem                                    4.1.5
# esda                                     2.5.1
# essentia                                 2.1b6.dev1110
# et-xmlfile                               1.1.0
# etils                                    1.6.0
# exceptiongroup                           1.2.0
# executing                                2.0.1
# explainable-ai-sdk                       1.3.3
# Farama-Notifications                     0.0.4
# fastai                                   2.7.14
# fastapi                                  0.108.0
# fastavro                                 1.9.3
# fastcore                                 1.5.29
# fastdownload                             0.0.7
# fasteners                                0.19
# fastjsonschema                           2.19.1
# fastprogress                             1.0.3
# fastrlock                                0.8.2
# fasttext                                 0.9.2
# feather-format                           0.4.1
# featuretools                             1.30.0
# filelock                                 3.13.1
# fiona                                    1.9.6
# fitter                                   1.7.0
# flake8                                   7.0.0
# flashtext                                2.7
# Flask                                    3.0.3
# flatbuffers                              23.5.26
# flax                                     0.8.2
# folium                                   0.16.0
# fonttools                                4.47.0
# fqdn                                     1.5.1
# frozendict                               2.4.2
# frozenlist                               1.4.1
# fsspec                                   2024.2.0
# funcy                                    2.0
# fury                                     0.10.0
# future                                   1.0.0
# fuzzywuzzy                               0.18.0
# gast                                     0.5.4
# gatspy                                   0.3
# gcsfs                                    2024.2.0
# gensim                                   4.3.2
# geographiclib                            2.0
# Geohash                                  1.0
# geojson                                  3.1.0
# geopandas                                0.14.3
# geoplot                                  0.5.1
# geopy                                    2.4.1
# geoviews                                 1.12.0
# ggplot                                   0.11.5
# giddy                                    2.3.5
# gitdb                                    4.0.11
# GitPython                                3.1.41
# google-ai-generativelanguage             0.6.2
# google-api-core                          2.11.1
# google-api-python-client                 2.126.0
# google-apitools                          0.5.31
# google-auth                              2.26.1
# google-auth-httplib2                     0.2.0
# google-auth-oauthlib                     1.2.0
# google-cloud-aiplatform                  0.6.0a1
# google-cloud-artifact-registry           1.10.0
# google-cloud-automl                      1.0.1
# google-cloud-bigquery                    2.34.4
# google-cloud-bigtable                    1.7.3
# google-cloud-core                        2.4.1
# google-cloud-datastore                   2.19.0
# google-cloud-dlp                         3.14.0
# google-cloud-jupyter-config              0.0.5
# google-cloud-language                    2.13.3
# google-cloud-monitoring                  2.18.0
# google-cloud-pubsub                      2.19.0
# google-cloud-pubsublite                  1.9.0
# google-cloud-recommendations-ai          0.7.1
# google-cloud-resource-manager            1.11.0
# google-cloud-spanner                     3.40.1
# google-cloud-storage                     1.44.0
# google-cloud-translate                   3.12.1
# google-cloud-videointelligence           2.13.3
# google-cloud-vision                      2.8.0
# google-crc32c                            1.5.0
# google-generativeai                      0.5.1
# google-pasta                             0.2.0
# google-resumable-media                   2.7.0
# googleapis-common-protos                 1.62.0
# gplearn                                  0.4.2
# gpustat                                  1.0.0
# gpxpy                                    1.6.2
# graphviz                                 0.20.3
# greenlet                                 3.0.3
# grpc-google-iam-v1                       0.12.7
# grpcio                                   1.51.1
# grpcio-status                            1.48.1
# gviz-api                                 1.10.0
# gym                                      0.26.2
# gym-notices                              0.0.8
# gymnasium                                0.29.0
# h11                                      0.14.0
# h2o                                      3.46.0.1
# h5netcdf                                 1.3.0
# h5py                                     3.10.0
# haversine                                2.8.1
# hdfs                                     2.7.3
# hep-ml                                   0.7.2
# hijri-converter                          2.3.1
# hmmlearn                                 0.3.2
# holidays                                 0.24
# holoviews                                1.18.3
# hpsklearn                                0.1.0
# html5lib                                 1.1
# htmlmin                                  0.1.12
# httpcore                                 1.0.5
# httplib2                                 0.21.0
# httptools                                0.6.1
# httpx                                    0.27.0
# huggingface-hub                          0.22.2
# hunspell                                 0.5.5
# hydra-slayer                             0.5.0
# hyperopt                                 0.2.7
# hypertools                               0.8.0
# idna                                     3.6
# igraph                                   0.11.4
# imagecodecs                              2024.1.1
# ImageHash                                4.3.1
# imageio                                  2.33.1
# imbalanced-learn                         0.12.2
# imgaug                                   0.4.0
# importlib-metadata                       6.11.0
# importlib-resources                      6.1.1
# inequality                               1.0.1
# iniconfig                                2.0.0
# ipydatawidgets                           4.3.5
# ipykernel                                6.28.0
# ipyleaflet                               0.18.2
# ipympl                                   0.7.0
# ipython                                  8.20.0
# ipython-genutils                         0.2.0
# ipython-sql                              0.5.0
# ipyvolume                                0.6.3
# ipyvue                                   1.11.0
# ipyvuetify                               1.9.4
# ipywebrtc                                0.6.0
# ipywidgets                               7.7.1
# isoduration                              20.11.0
# isort                                    5.13.2
# isoweek                                  1.3.3
# itsdangerous                             2.2.0
# Janome                                   0.5.0
# jaraco.classes                           3.3.0
# jax                                      0.4.23
# jax-jumpy                                1.0.0
# jaxlib                                   0.4.23.dev20240116
# jedi                                     0.19.1
# jeepney                                  0.8.0
# jieba                                    0.42.1
# Jinja2                                   3.1.2
# jmespath                                 1.0.1
# joblib                                   1.4.0
# json5                                    0.9.14
# jsonpatch                                1.33
# jsonpointer                              2.4
# jsonschema                               4.20.0
# jsonschema-specifications                2023.12.1
# jupyter_client                           7.4.9
# jupyter-console                          6.6.3
# jupyter_core                             5.7.1
# jupyter-events                           0.9.0
# jupyter-http-over-ws                     0.0.8
# jupyter-lsp                              1.5.1
# jupyter_server                           2.12.5
# jupyter_server_fileid                    0.9.1
# jupyter-server-mathjax                   0.2.6
# jupyter_server_proxy                     4.1.0
# jupyter_server_terminals                 0.5.1
# jupyter_server_ydoc                      0.8.0
# jupyter-ydoc                             0.2.5
# jupyterlab                               4.1.6
# jupyterlab_git                           0.44.0
# jupyterlab-lsp                           5.1.0
# jupyterlab_pygments                      0.3.0
# jupyterlab_server                        2.25.2
# jupyterlab-widgets                       3.0.9
# jupytext                                 1.16.0
# kaggle                                   1.6.12
# kaggle-environments                      1.14.3
# kagglehub                                0.2.3
# keras                                    3.2.1
# keras-cv                                 0.8.2
# keras-nlp                                0.9.3
# keras-tuner                              1.4.6
# kernels-mixer                            0.0.7
# keyring                                  24.3.0
# keyrings.google-artifactregistry-auth    1.1.2
# kfp                                      2.5.0
# kfp-pipeline-spec                        0.2.2
# kfp-server-api                           2.0.5
# kiwisolver                               1.4.5
# kmapper                                  2.0.1
# kmodes                                   0.12.2
# korean-lunar-calendar                    0.3.1
# kornia                                   0.7.2
# kornia_rs                                0.1.3
# kt-legacy                                1.0.5
# kubernetes                               26.1.0
# langcodes                                3.3.0
# langid                                   1.1.6
# lazy_loader                              0.3
# learntools                               0.3.4
# leven                                    1.0.4
# libclang                                 16.0.6
# libmambapy                               1.5.0
# libpysal                                 4.9.2
# librosa                                  0.10.1
# lightgbm                                 4.2.0
# lightning-utilities                      0.11.2
# lime                                     0.2.0.1
# line-profiler                            4.1.2
# linkify-it-py                            2.0.3
# llvmlite                                 0.41.1
# lml                                      0.1.0
# locket                                   1.0.0
# loguru                                   0.7.2
# LunarCalendar                            0.0.9
# lxml                                     5.2.1
# lz4                                      4.3.3
# Mako                                     1.3.3
# mamba                                    1.5.0
# mapclassify                              2.6.1
# Markdown                                 3.5.2
# markdown-it-py                           3.0.0
# MarkupSafe                               2.1.3
# marshmallow                              3.21.1
# matplotlib                               3.7.5
# matplotlib-inline                        0.1.6
# matplotlib-venn                          0.11.10
# mccabe                                   0.7.0
# mdit-py-plugins                          0.4.0
# mdurl                                    0.1.2
# memory-profiler                          0.61.0
# menuinst                                 2.0.1
# mercantile                               1.2.1
# mgwr                                     2.2.1
# missingno                                0.5.2
# mistune                                  0.8.4
# mizani                                   0.11.1
# ml-dtypes                                0.2.0
# mlcrate                                  0.2.0
# mlens                                    0.2.3
# mlxtend                                  0.23.1
# mne                                      1.6.1
# mnist                                    0.2.2
# momepy                                   0.7.0
# more-itertools                           10.2.0
# mpld3                                    0.5.10
# mpmath                                   1.3.0
# msgpack                                  1.0.7
# multidict                                6.0.4
# multimethod                              1.10
# multipledispatch                         1.0.0
# multiprocess                             0.70.16
# munkres                                  1.1.4
# murmurhash                               1.0.10
# mypy-extensions                          1.0.0
# namex                                    0.0.8
# nb_conda                                 2.2.1
# nb-conda-kernels                         2.3.1
# nbclassic                                1.0.0
# nbclient                                 0.5.13
# nbconvert                                6.4.5
# nbdime                                   3.2.0
# nbformat                                 5.9.2
# ndindex                                  1.8
# nest-asyncio                             1.5.8
# networkx                                 3.2.1
# nibabel                                  5.2.1
# nilearn                                  0.10.4
# ninja                                    1.11.1.1
# nltk                                     3.2.4
# nose                                     1.3.7
# notebook                                 6.5.4
# notebook_executor                        0.2
# notebook_shim                            0.2.3
# numba                                    0.58.1
# numexpr                                  2.10.0
# numpy                                    1.26.4
# nvidia-ml-py                             11.495.46
# nvtx                                     0.2.10
# oauth2client                             4.1.3
# oauthlib                                 3.2.2
# objsize                                  0.6.1
# odfpy                                    1.4.1
# olefile                                  0.47
# onnx                                     1.16.0
# opencensus                               0.11.4
# opencensus-context                       0.1.3
# opencv-contrib-python                    4.9.0.80
# opencv-python                            4.9.0.80
# opencv-python-headless                   4.9.0.80
# openpyxl                                 3.1.2
# openslide-python                         1.3.1
# opentelemetry-api                        1.22.0
# opentelemetry-exporter-otlp              1.22.0
# opentelemetry-exporter-otlp-proto-common 1.22.0
# opentelemetry-exporter-otlp-proto-grpc   1.22.0
# opentelemetry-exporter-otlp-proto-http   1.22.0
# opentelemetry-proto                      1.22.0
# opentelemetry-sdk                        1.22.0
# opentelemetry-semantic-conventions       0.43b0
# opt-einsum                               3.3.0
# optax                                    0.2.2
# optree                                   0.11.0
# optuna                                   3.6.1
# orbax-checkpoint                         0.5.9
# ordered-set                              4.1.0
# orjson                                   3.9.10
# ortools                                  9.4.1874
# osmnx                                    1.9.2
# overrides                                7.4.0
# packaging                                21.3
# pandas                                   2.1.4
# pandas-datareader                        0.10.0
# pandas-profiling                         3.6.6
# pandas-summary                           0.2.0
# pandasql                                 0.7.3
# pandocfilters                            1.5.0
# panel                                    1.4.1
# papermill                                2.5.0
# param                                    2.1.0
# parso                                    0.8.3
# partd                                    1.4.1
# path                                     16.14.0
# path.py                                  12.5.0
# pathos                                   0.3.2
# pathy                                    0.10.3
# patsy                                    0.5.6
# pdf2image                                1.17.0
# pettingzoo                               1.24.0
# pexpect                                  4.8.0
# phik                                     0.12.4
# pickleshare                              0.7.5
# Pillow                                   9.5.0
# pip                                      23.3.2
# pkgutil_resolve_name                     1.3.10
# platformdirs                             4.2.0
# plotly                                   5.18.0
# plotly-express                           0.4.1
# plotnine                                 0.13.4
# pluggy                                   1.4.0
# pointpats                                2.4.0
# polars                                   0.20.21
# polyglot                                 16.7.4
# pooch                                    1.8.1
# pox                                      0.3.4
# ppca                                     0.0.4
# ppft                                     1.7.6.8
# preprocessing                            0.1.13
# preshed                                  3.0.9
# prettytable                              3.9.0
# progressbar2                             4.4.2
# prometheus-client                        0.19.0
# promise                                  2.3
# prompt-toolkit                           3.0.42
# prophet                                  1.1.1
# proto-plus                               1.23.0
# protobuf                                 3.20.3
# psutil                                   5.9.3
# ptyprocess                               0.7.0
# pudb                                     2024.1
# PuLP                                     2.8.0
# pure-eval                                0.2.2
# py-cpuinfo                               9.0.0
# py-spy                                   0.3.14
# py4j                                     0.10.9.7
# pyaml                                    23.12.0
# PyArabic                                 0.6.15
# pyarrow                                  15.0.2
# pyarrow-hotfix                           0.6
# pyasn1                                   0.5.1
# pyasn1-modules                           0.3.0
# pybind11                                 2.12.0
# pyclipper                                1.3.0.post5
# pycodestyle                              2.11.1
# pycosat                                  0.6.6
# pycparser                                2.21
# pycryptodome                             3.20.0
# pyct                                     0.5.0
# pycuda                                   2024.1
# pydantic                                 2.5.3
# pydantic_core                            2.14.6
# pydegensac                               0.1.2
# pydicom                                  2.4.4
# pydocstyle                               6.3.0
# pydot                                    1.4.2
# pydub                                    0.25.1
# pyemd                                    1.0.0
# pyerfa                                   2.0.1.4
# pyexcel-io                               0.6.6
# pyexcel-ods                              0.6.0
# pyflakes                                 3.2.0
# pygltflib                                1.16.2
# Pygments                                 2.17.2
# PyJWT                                    2.8.0
# pykalman                                 0.9.7
# pyLDAvis                                 3.4.1
# pylibraft                                23.8.0
# pylint                                   3.1.0
# pymc3                                    3.11.4
# PyMeeus                                  0.5.12
# pymongo                                  3.13.0
# Pympler                                  1.0.1
# pynndescent                              0.5.12
# pynvml                                   11.4.1
# pynvrtc                                  9.2
# pyOpenSSL                                23.3.0
# pyparsing                                3.1.1
# pypdf                                    4.2.0
# pyproj                                   3.6.1
# pysal                                    24.1
# pyshp                                    2.3.1
# PySocks                                  1.7.1
# pytesseract                              0.3.10
# pytest                                   8.1.1
# python-bidi                              0.4.2
# python-dateutil                          2.9.0.post0
# python-dotenv                            1.0.0
# python-json-logger                       2.0.7
# python-louvain                           0.16
# python-lsp-jsonrpc                       1.1.2
# python-lsp-server                        1.11.0
# python-slugify                           8.0.4
# python-utils                             3.8.2
# pythreejs                                2.4.2
# pytoolconfig                             1.3.1
# pytools                                  2024.1.1
# pytorch-ignite                           0.5.0.post2
# pytorch-lightning                        2.2.2
# pytz                                     2023.3.post1
# pyu2f                                    0.1.5
# PyUpSet                                  0.1.1.post7
# pyviz_comms                              3.0.2
# PyWavelets                               1.5.0
# PyYAML                                   6.0.1
# pyzmq                                    24.0.1
# qgrid                                    1.3.1
# qtconsole                                5.5.1
# QtPy                                     2.4.1
# quantecon                                0.7.2
# qudida                                   0.0.4
# raft-dask                                23.8.0
# rasterio                                 1.3.10
# rasterstats                              0.19.0
# ray                                      2.9.0
# ray-cpp                                  2.9.0
# referencing                              0.32.1
# regex                                    2023.12.25
# requests                                 2.31.0
# requests-oauthlib                        1.3.1
# requests-toolbelt                        0.10.1
# retrying                                 1.3.3
# rfc3339-validator                        0.1.4
# rfc3986-validator                        0.1.1
# rgf-python                               3.12.0
# rich                                     13.7.0
# rich-click                               1.7.4
# rmm                                      23.8.0
# rope                                     1.13.0
# rpds-py                                  0.16.2
# rsa                                      4.9
# Rtree                                    1.2.0
# ruamel.yaml                              0.17.40
# ruamel.yaml.clib                         0.2.7
# ruamel-yaml-conda                        0.15.100
# s2sphere                                 0.2.5
# s3fs                                     2024.2.0
# s3transfer                               0.6.2
# safetensors                              0.4.3
# scattertext                              0.1.19
# scikit-image                             0.22.0
# scikit-learn                             1.2.2
# scikit-learn-intelex                     2024.3.0
# scikit-multilearn                        0.2.0
# scikit-optimize                          0.10.1
# scikit-plot                              0.3.7
# scikit-surprise                          1.1.3
# scipy                                    1.11.4
# seaborn                                  0.12.2
# SecretStorage                            3.3.3
# segment_anything                         1.0
# segregation                              2.5
# semver                                   3.0.2
# Send2Trash                               1.8.2
# sentencepiece                            0.2.0
# sentry-sdk                               1.45.0
# setproctitle                             1.3.3
# setuptools                               69.0.3
# setuptools-git                           1.2
# setuptools-scm                           8.0.4
# shap                                     0.44.1
# Shapely                                  1.8.5.post1
# shellingham                              1.5.4
# Shimmy                                   1.3.0
# simpervisor                              1.0.0
# SimpleITK                                2.3.1
# simplejson                               3.19.2
# six                                      1.16.0
# sklearn-pandas                           2.2.0
# slicer                                   0.0.7
# smart-open                               6.4.0
# smmap                                    5.0.1
# sniffio                                  1.3.0
# snowballstemmer                          2.2.0
# snuggs                                   1.4.7
# sortedcontainers                         2.4.0
# soundfile                                0.12.1
# soupsieve                                2.5
# soxr                                     0.3.7
# spacy                                    3.7.3
# spacy-legacy                             3.0.12
# spacy-loggers                            1.0.5
# spaghetti                                1.7.5.post1
# spectral                                 0.23.1
# spglm                                    1.1.0
# sphinx-rtd-theme                         0.2.4
# spint                                    1.0.7
# splot                                    1.1.5.post1
# spopt                                    0.6.0
# spreg                                    1.4.2
# spvcm                                    0.3.0
# SQLAlchemy                               2.0.25
# sqlparse                                 0.4.4
# squarify                                 0.4.3
# srsly                                    2.4.8
# stable-baselines3                        2.1.0
# stack-data                               0.6.2
# stanio                                   0.5.0
# starlette                                0.32.0.post1
# statsmodels                              0.14.1
# stemming                                 1.0.1
# stop-words                               2018.7.23
# stopit                                   1.1.2
# stumpy                                   1.12.0
# sympy                                    1.12
# tables                                   3.9.2
# tabulate                                 0.9.0
# tangled-up-in-unicode                    0.2.0
# tbb                                      2021.12.0
# tblib                                    3.0.0
# tenacity                                 8.2.3
# tensorboard                              2.15.1
# tensorboard-data-server                  0.7.2
# tensorboard-plugin-profile               2.15.0
# tensorboardX                             2.6.2.2
# tensorflow                               2.15.0
# tensorflow-cloud                         0.1.16
# tensorflow-datasets                      4.9.4
# tensorflow-decision-forests              1.8.1
# tensorflow-estimator                     2.15.0
# tensorflow-hub                           0.16.1
# tensorflow-io                            0.35.0
# tensorflow-io-gcs-filesystem             0.35.0
# tensorflow-metadata                      0.14.0
# tensorflow-probability                   0.23.0
# tensorflow-serving-api                   2.14.1
# tensorflow-text                          2.15.0
# tensorflow-transform                     0.14.0
# tensorstore                              0.1.56
# termcolor                                2.4.0
# terminado                                0.18.0
# testpath                                 0.6.0
# text-unidecode                           1.3
# textblob                                 0.18.0.post0
# texttable                                1.7.0
# tf_keras                                 2.15.1
# tfp-nightly                              0.24.0.dev0
# Theano                                   1.0.5
# Theano-PyMC                              1.1.2
# thinc                                    8.2.2
# threadpoolctl                            3.2.0
# tifffile                                 2023.12.9
# timm                                     0.9.16
# tinycss2                                 1.2.1
# tobler                                   0.11.2
# tokenizers                               0.15.2
# toml                                     0.10.2
# tomli                                    2.0.1
# tomlkit                                  0.12.4
# toolz                                    0.12.1
# torch                                    2.1.2
# torchaudio                               2.1.2
# torchdata                                0.7.1
# torchinfo                                1.8.0
# torchmetrics                             1.3.2
# torchtext                                0.16.2
# torchvision                              0.16.2
# tornado                                  6.3.3
# TPOT                                     0.12.1
# tqdm                                     4.66.1
# traceml                                  1.0.8
# traitlets                                5.9.0
# traittypes                               0.2.1
# transformers                             4.39.3
# treelite                                 3.2.0
# treelite-runtime                         3.2.0
# truststore                               0.8.0
# trx-python                               0.2.9
# tsfresh                                  0.20.2
# typeguard                                4.1.5
# typer                                    0.9.0
# types-python-dateutil                    2.8.19.20240106
# typing_extensions                        4.9.0
# typing-inspect                           0.9.0
# typing-utils                             0.1.0
# tzdata                                   2023.4
# uc-micro-py                              1.0.3
# ucx-py                                   0.33.0
# ujson                                    5.9.0
# umap-learn                               0.5.6
# unicodedata2                             15.1.0
# update-checker                           0.18.0
# uri-template                             1.3.0
# uritemplate                              3.0.1
# urllib3                                  1.26.18
# urwid                                    2.6.10
# urwid_readline                           0.14
# uvicorn                                  0.25.0
# uvloop                                   0.19.0
# vaex                                     4.17.0
# vaex-astro                               0.9.3
# vaex-core                                4.17.1
# vaex-hdf5                                0.14.1
# vaex-jupyter                             0.8.2
# vaex-ml                                  0.18.3
# vaex-server                              0.9.0
# vaex-viz                                 0.5.4
# vec_noise                                1.1.4
# vecstack                                 0.4.0
# virtualenv                               20.21.0
# visions                                  0.7.5
# vowpalwabbit                             9.9.0
# vtk                                      9.3.0
# Wand                                     0.6.13
# wandb                                    0.16.6
# wasabi                                   1.1.2
# watchfiles                               0.21.0
# wavio                                    0.0.8
# wcwidth                                  0.2.13
# weasel                                   0.3.4
# webcolors                                1.13
# webencodings                             0.5.1
# websocket-client                         1.7.0
# websockets                               12.0
# Werkzeug                                 3.0.2
# wfdb                                     4.1.2
# whatthepatch                             1.0.5
# wheel                                    0.42.0
# widgetsnbextension                       3.6.6
# witwidget                                1.8.1
# woodwork                                 0.30.0
# wordcloud                                1.9.3
# wordsegment                              1.3.1
# wrapt                                    1.14.1
# xarray                                   2024.3.0
# xarray-einstats                          0.7.0
# xgboost                                  2.0.3
# xvfbwrapper                              0.2.9
# xxhash                                   3.4.1
# xyzservices                              2024.4.0
# y-py                                     0.6.2
# yapf                                     0.40.2
# yarl                                     1.9.3
# ydata-profiling                          4.6.4
# yellowbrick                              1.5
# ypy-websocket                            0.8.4
# zict                                     3.0.0
# zipp                                     3.17.0
# zstandard                                0.22.0
# Note: you may need to restart the kernel to use updated packages.
